# %%
import pandas as pd
import numpy as np

cleaned_reviews = "air_nz_cleaned_data.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  food_&_beverages  ground_service  \
# 0                    5.0               5.0             5.0
# 1                    5.0              -1.0             5.0
# 2                    4.0              -1.0             1.0
# 3                    3.0               2.0             1.0
# 4                    5.0               4.0             4.0
# ..                   ...               ...             ...
# 744                  2.0               3.0            -1.0
# 745                  5.0               5.0            -1.0
# 746                  5.0               5.0            -1.0
# 747                  3.0               4.0            -1.0
# 748                  3.0               4.0            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  \
# 0                    4.0              5.0         True
# 1                   -1.0              1.0        False
# 2                   -1.0              1.0        False
# 3                    1.0              2.0        False
# 4                   -1.0              5.0         True
# ..                   ...              ...          ...
# 744                 -1.0              2.0        False
# 745                 -1.0              4.0         True
# 746                 -1.0              5.0         True
# 747                 -1.0              3.0        False
# 748                 -1.0              2.0        False
#
#      inflight_entertainment  verified_status  \
# 0                      -1.0            False
# 1                      -1.0            False
# 2                      -1.0             True
# 3                       2.0            False
# 4                      -1.0             True
# ..                      ...              ...
# 744                     4.0            False
# 745                     5.0            False
# 746                     5.0            False
# 747                     1.0            False
# 748                     3.0            False
#
#                                         review_content
# 0    I was honestly quite surprised about Air New Z...
# 1    Air New Zealand domestic service is getting wo...
# 2    Air New Zealand bumped us off our flight on th...
# 3    Very unfortunately the service, care, and qual...
# 4    Check-in was efficient; boarding and departure...
# ..                                                 ...
# 744  I have flown with Air New Zealand for several ...
# 745  Flew Wellington-San Francisco (via Auckland). ...
# 746  Flew Premium Economy from LAX to AKL on a 777-...
# 747  Adelaide to Auckland April 28 2013. Usual incr...
# 748  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
# [749 rows x 18 columns]

# %%
reviews_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content'],
#       dtype='object')

# %% [markdown]
# # What are the average ratings for specific service categories (e.g., seat comfort, cabin staff service, food & beverages, etc.)?

# %%
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service','wifi_&_connectivity','value_for_money','inflight_entertainment']

# Average rating for each category
average_ratings_by_category = reviews_df[rating_columns].mean()
print("Average Ratings by Category:")
print(average_ratings_by_category)
# Out:
# Average Ratings by Category:
# seat_comfort              2.941255
# cabin_staff_service       3.174900
# food_&_beverages          2.461949
# ground_service            1.743658
# wifi_&_connectivity      -0.194927
# value_for_money           2.859813
# inflight_entertainment    2.341789
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Round up aaverage rating per category
average_ratings_by_category = np.ceil(reviews_df[rating_columns].mean())

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x=average_ratings_by_category.index, y=average_ratings_by_category.values, palette="viridis")

plt.title("Average Rating per Category (Rounded Up)", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45, ha='right')

for i in range(len(average_ratings_by_category)):
    bar_plot.text(i, average_ratings_by_category.values[i] + 0.1, str(int(average_ratings_by_category.values[i])), 
                  ha='center', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3891546184.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x=average_ratings_by_category.index, y=average_ratings_by_category.values, palette="viridis")

# %% [markdown]
# # What is the average overall rating of Air New Zealand based on customer reviews?

# %%
# Ratings converted to numeric if they are in string format
reviews_df['rating'] = pd.to_numeric(reviews_df['rating'], errors='coerce')

# Overall average rating
average_rating = reviews_df['rating'].mean()
print(f"Average Rating: {average_rating:.2f}")
# Out:
# Average Rating: 5.25

# %%
labels = ['Average Rating', 'Remaining']
sizes = [average_rating, 10 - average_rating]
colors = ['#4caf50', '#f0f0f0']  

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(sizes, labels=labels, colors=colors, startangle=90, autopct='%1.1f%%',
       pctdistance=0.85, wedgeprops={'edgecolor': 'white', 'linewidth': 2})

centre_circle = plt.Circle((0, 0), 0.70, fc='white', linewidth=1.25)
ax.add_artist(centre_circle)

plt.title(f'Average Rating: {average_rating:.2f}/10', fontsize=18, color='#333', fontweight='bold')
plt.setp(ax.texts, fontweight='bold', color='#555', fontsize=12)
plt.show()

# %% [markdown]
# # How do missing WiFi & Connectivity Ratings affect the overall average rating?

# %%
# Plot distribution of 'wifi_&_connectivity' ratings
plt.figure(figsize=(10, 6))
sns.histplot(reviews_df['wifi_&_connectivity'], bins=20, kde=True, color="skyblue")
plt.title("Distribution of WiFi & Connectivity Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
# Count of -1.0 values in 'wifi_&_connectivity'
negative_count = (reviews_df['wifi_&_connectivity'] == -1.0).sum()
total_count = len(reviews_df)
print(f"Number of -1.0 ratings: {negative_count}")
print(f"Total number of ratings: {total_count}")
# Out:
# Number of -1.0 ratings: 574
# Total number of ratings: 749

# %%
# Filter out -1.0 values and calculate the mean
valid_wifi_ratings = reviews_df[reviews_df['wifi_&_connectivity'] != -1.0]['wifi_&_connectivity']
average_valid_wifi_rating = valid_wifi_ratings.mean()

print(f"Average WiFi & Connectivity Rating (excluding -1.0): {average_valid_wifi_rating}")
# Out:
# Average WiFi & Connectivity Rating (excluding -1.0): 2.4457142857142857

# %%
# Data for comparison
average_ratings_comparison = pd.Series({
    'With -1.0': reviews_df['wifi_&_connectivity'].mean(),
    'Without -1.0': average_valid_wifi_rating
})

plt.figure(figsize=(8, 5))
sns.barplot(x=average_ratings_comparison.index, y=average_ratings_comparison.values, palette="viridis")
plt.title("Comparison of Average WiFi & Connectivity Rating")
plt.xlabel("Including/Excluding -1.0 Values")
plt.ylabel("Average Rating")
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3117925003.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_ratings_comparison.index, y=average_ratings_comparison.values, palette="viridis")

# %% [markdown]
# # What is the overall sentiment distribution of the reviews?

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import confusion_matrix, classification_report

# %%
reviews_df = pd.read_csv('air_nz_cleaned_data.csv')

# Check for and handle missing values
reviews_df.dropna(subset=['review_content'], inplace=True)

reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  food_&_beverages  ground_service  \
# 0                    5.0               5.0             5.0
# 1                    5.0              -1.0             5.0
# 2                    4.0              -1.0             1.0
# 3                    3.0               2.0             1.0
# 4                    5.0               4.0             4.0
# ..                   ...               ...             ...
# 744                  2.0               3.0            -1.0
# 745                  5.0               5.0            -1.0
# 746                  5.0               5.0            -1.0
# 747                  3.0               4.0            -1.0
# 748                  3.0               4.0            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  \
# 0                    4.0              5.0         True
# 1                   -1.0              1.0        False
# 2                   -1.0              1.0        False
# 3                    1.0              2.0        False
# 4                   -1.0              5.0         True
# ..                   ...              ...          ...
# 744                 -1.0              2.0        False
# 745                 -1.0              4.0         True
# 746                 -1.0              5.0         True
# 747                 -1.0              3.0        False
# 748                 -1.0              2.0        False
#
#      inflight_entertainment  verified_status  \
# 0                      -1.0            False
# 1                      -1.0            False
# 2                      -1.0             True
# 3                       2.0            False
# 4                      -1.0             True
# ..                      ...              ...
# 744                     4.0            False
# 745                     5.0            False
# 746                     5.0            False
# 747                     1.0            False
# 748                     3.0            False
#
#                                         review_content
# 0    I was honestly quite surprised about Air New Z...
# 1    Air New Zealand domestic service is getting wo...
# 2    Air New Zealand bumped us off our flight on th...
# 3    Very unfortunately the service, care, and qual...
# 4    Check-in was efficient; boarding and departure...
# ..                                                 ...
# 744  I have flown with Air New Zealand for several ...
# 745  Flew Wellington-San Francisco (via Auckland). ...
# 746  Flew Premium Economy from LAX to AKL on a 777-...
# 747  Adelaide to Auckland April 28 2013. Usual incr...
# 748  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
# [749 rows x 18 columns]

# %%
# Text cleaning function
def clean_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply text cleaning
reviews_df['review_content'] = reviews_df['review_content'].apply(clean_text)
reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  food_&_beverages  ground_service  \
# 0                    5.0               5.0             5.0
# 1                    5.0              -1.0             5.0
# 2                    4.0              -1.0             1.0
# 3                    3.0               2.0             1.0
# 4                    5.0               4.0             4.0
# ..                   ...               ...             ...
# 744                  2.0               3.0            -1.0
# 745                  5.0               5.0            -1.0
# 746                  5.0               5.0            -1.0
# 747                  3.0               4.0            -1.0
# 748                  3.0               4.0            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  \
# 0                    4.0              5.0         True
# 1                   -1.0              1.0        False
# 2                   -1.0              1.0        False
# 3                    1.0              2.0        False
# 4                   -1.0              5.0         True
# ..                   ...              ...          ...
# 744                 -1.0              2.0        False
# 745                 -1.0              4.0         True
# 746                 -1.0              5.0         True
# 747                 -1.0              3.0        False
# 748                 -1.0              2.0        False
#
#      inflight_entertainment  verified_status  \
# 0                      -1.0            False
# 1                      -1.0            False
# 2                      -1.0             True
# 3                       2.0            False
# 4                      -1.0             True
# ..                      ...              ...
# 744                     4.0            False
# 745                     5.0            False
# 746                     5.0            False
# 747                     1.0            False
# 748                     3.0            False
#
#                                         review_content
# 0    i was honestly quite surprised about air new z...
# 1    air new zealand domestic service is getting wo...
# 2    air new zealand bumped us off our flight on th...
# 3    very unfortunately the service care and qualit...
# 4    checkin was efficient boarding and departure w...
# ..                                                 ...
# 744  i have flown with air new zealand for several ...
# 745  flew wellingtonsan francisco via auckland boug...
# 746  flew premium economy from lax to akl on a 7772...
# 747  adelaide to auckland april 28 2013 usual incre...
# 748  b747400 premium economy sfoakl b767 works akls...
#
# [749 rows x 18 columns]

# %%
# Define sentiment analysis functions
def get_sentiment_textblob(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0:
        return 'Positive'
    elif polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# Apply sentiment analysis using TextBlob
reviews_df['textblob_sentiment'] = reviews_df['review_content'].apply(get_sentiment_textblob)
reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  food_&_beverages  ground_service  \
# 0                    5.0               5.0             5.0
# 1                    5.0              -1.0             5.0
# 2                    4.0              -1.0             1.0
# 3                    3.0               2.0             1.0
# 4                    5.0               4.0             4.0
# ..                   ...               ...             ...
# 744                  2.0               3.0            -1.0
# 745                  5.0               5.0            -1.0
# 746                  5.0               5.0            -1.0
# 747                  3.0               4.0            -1.0
# 748                  3.0               4.0            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  \
# 0                    4.0              5.0         True
# 1                   -1.0              1.0        False
# 2                   -1.0              1.0        False
# 3                    1.0              2.0        False
# 4                   -1.0              5.0         True
# ..                   ...              ...          ...
# 744                 -1.0              2.0        False
# 745                 -1.0              4.0         True
# 746                 -1.0              5.0         True
# 747                 -1.0              3.0        False
# 748                 -1.0              2.0        False
#
#      inflight_entertainment  verified_status  \
# 0                      -1.0            False
# 1                      -1.0            False
# 2                      -1.0             True
# 3                       2.0            False
# 4                      -1.0             True
# ..                      ...              ...
# 744                     4.0            False
# 745                     5.0            False
# 746                     5.0            False
# 747                     1.0            False
# 748                     3.0            False
#
#                                         review_content textblob_sentiment
# 0    i was honestly quite surprised about air new z...           Positive
# 1    air new zealand domestic service is getting wo...           Negative
# 2    air new zealand bumped us off our flight on th...           Negative
# 3    very unfortunately the service care and qualit...           Negative
# 4    checkin was efficient boarding and departure w...           Positive
# ..                                                 ...                ...
# 744  i have flown with air new zealand for several ...           Positive
# 745  flew wellingtonsan francisco via auckland boug...           Positive
# 746  flew premium economy from lax to akl on a 7772...           Positive
# 747  adelaide to auckland april 28 2013 usual incre...           Positive
# 748  b747400 premium economy sfoakl b767 works akls...           Negative
#
# [749 rows x 19 columns]

# %%
# Calculate sentiment counts
sentiment_counts = reviews_df['textblob_sentiment'].value_counts()
sentiment_counts
# Out:
# textblob_sentiment
# Positive    540
# Negative    206
# Neutral       3
# Name: count, dtype: int64

# %%
# Plot sentiment distribution
plt.figure(figsize=(10, 7))
colors = ['#4CAF50', '#FFC107', '#F44336']  # Colors for Positive, Neutral, Negative
plt.bar(sentiment_counts.index, sentiment_counts.values, color=colors, edgecolor='black', alpha=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Sentiment', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Distribution of Sentiment Categories (TextBlob)', fontsize=16, fontweight='bold')
for i, count in enumerate(sentiment_counts.values):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
def get_sentiment_vader(text):
    analyzer = SentimentIntensityAnalyzer()
    score = analyzer.polarity_scores(text)['compound']
    if score > 0.05:
        return 'Positive'
    elif score < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis using VADER
reviews_df['vader_sentiment'] = reviews_df['review_content'].apply(get_sentiment_vader)
reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  food_&_beverages  ground_service  \
# 0                    5.0               5.0             5.0
# 1                    5.0              -1.0             5.0
# 2                    4.0              -1.0             1.0
# 3                    3.0               2.0             1.0
# 4                    5.0               4.0             4.0
# ..                   ...               ...             ...
# 744                  2.0               3.0            -1.0
# 745                  5.0               5.0            -1.0
# 746                  5.0               5.0            -1.0
# 747                  3.0               4.0            -1.0
# 748                  3.0               4.0            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  \
# 0                    4.0              5.0         True
# 1                   -1.0              1.0        False
# 2                   -1.0              1.0        False
# 3                    1.0              2.0        False
# 4                   -1.0              5.0         True
# ..                   ...              ...          ...
# 744                 -1.0              2.0        False
# 745                 -1.0              4.0         True
# 746                 -1.0              5.0         True
# 747                 -1.0              3.0        False
# 748                 -1.0              2.0        False
#
#      inflight_entertainment  verified_status  \
# 0                      -1.0            False
# 1                      -1.0            False
# 2                      -1.0             True
# 3                       2.0            False
# 4                      -1.0             True
# ..                      ...              ...
# 744                     4.0            False
# 745                     5.0            False
# 746                     5.0            False
# 747                     1.0            False
# 748                     3.0            False
#
#                                         review_content textblob_sentiment  \
# 0    i was honestly quite surprised about air new z...           Positive
# 1    air new zealand domestic service is getting wo...           Negative
# 2    air new zealand bumped us off our flight on th...           Negative
# 3    very unfortunately the service care and qualit...           Negative
# 4    checkin was efficient boarding and departure w...           Positive
# ..                                                 ...                ...
# 744  i have flown with air new zealand for several ...           Positive
# 745  flew wellingtonsan francisco via auckland boug...           Positive
# 746  flew premium economy from lax to akl on a 7772...           Positive
# 747  adelaide to auckland april 28 2013 usual incre...           Positive
# 748  b747400 premium economy sfoakl b767 works akls...           Negative
#
#     vader_sentiment
# 0          Positive
# 1          Negative
# 2          Negative
# 3          Negative
# 4          Positive
# ..              ...
# 744        Positive
# 745        Positive
# 746        Positive
# 747        Positive
# 748        Positive
#
# [749 rows x 20 columns]

# %%
# Calculate sentiment counts
vader_sentiment_counts = reviews_df['vader_sentiment'].value_counts()
vader_sentiment_counts
# Out:
# vader_sentiment
# Positive    457
# Negative    281
# Neutral      11
# Name: count, dtype: int64

# %%
# Plot sentiment distribution
plt.figure(figsize=(10, 7))
colors = ['#4CAF50', '#FFC107', '#F44336']  # Colors for Positive, Neutral, Negative
plt.bar(vader_sentiment_counts.index, vader_sentiment_counts.values, color=colors, edgecolor='black', alpha=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Sentiment', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Distribution of Sentiment Categories (VADER)', fontsize=16, fontweight='bold')
for i, count in enumerate(vader_sentiment_counts.values):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Define function to map ratings to sentiment
def map_rating_to_sentiment(rating):
    if rating >= 8:
        return 'Positive'
    elif rating >= 4:
        return 'Neutral'
    else:
        return 'Negative'
    
# Apply rating to sentiment mapping
reviews_df['rating_sentiment'] = reviews_df['rating'].apply(map_rating_to_sentiment)
reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  ...  ground_service  wifi_&_connectivity  \
# 0                    5.0  ...             5.0                  4.0
# 1                    5.0  ...             5.0                 -1.0
# 2                    4.0  ...             1.0                 -1.0
# 3                    3.0  ...             1.0                  1.0
# 4                    5.0  ...             4.0                 -1.0
# ..                   ...  ...             ...                  ...
# 744                  2.0  ...            -1.0                 -1.0
# 745                  5.0  ...            -1.0                 -1.0
# 746                  5.0  ...            -1.0                 -1.0
# 747                  3.0  ...            -1.0                 -1.0
# 748                  3.0  ...            -1.0                 -1.0
#
#      value_for_money  recommended  inflight_entertainment  verified_status  \
# 0                5.0         True                    -1.0            False
# 1                1.0        False                    -1.0            False
# 2                1.0        False                    -1.0             True
# 3                2.0        False                     2.0            False
# 4                5.0         True                    -1.0             True
# ..               ...          ...                     ...              ...
# 744              2.0        False                     4.0            False
# 745              4.0         True                     5.0            False
# 746              5.0         True                     5.0            False
# 747              3.0        False                     1.0            False
# 748              2.0        False                     3.0            False
#
#                                         review_content textblob_sentiment  \
# 0    i was honestly quite surprised about air new z...           Positive
# 1    air new zealand domestic service is getting wo...           Negative
# 2    air new zealand bumped us off our flight on th...           Negative
# 3    very unfortunately the service care and qualit...           Negative
# 4    checkin was efficient boarding and departure w...           Positive
# ..                                                 ...                ...
# 744  i have flown with air new zealand for several ...           Positive
# 745  flew wellingtonsan francisco via auckland boug...           Positive
# 746  flew premium economy from lax to akl on a 7772...           Positive
# 747  adelaide to auckland april 28 2013 usual incre...           Positive
# 748  b747400 premium economy sfoakl b767 works akls...           Negative
#
#     vader_sentiment rating_sentiment
# 0          Positive         Positive
# 1          Negative         Negative
# 2          Negative         Negative
# 3          Negative         Negative
# 4          Positive         Positive
# ..              ...              ...
# 744        Positive         Negative
# 745        Positive         Positive
# 746        Positive         Positive
# 747        Positive          Neutral
# 748        Positive          Neutral
#
# [749 rows x 21 columns]

# %%
# Sample reviews for each sentiment type
def sample_reviews(df, sentiment, n=2):
    return df[df['textblob_sentiment'] == sentiment].sample(n=n)

# Sample 2 reviews for each sentiment type
positive_samples = sample_reviews(reviews_df, 'Positive')
neutral_samples = sample_reviews(reviews_df, 'Neutral')
negative_samples = sample_reviews(reviews_df, 'Negative')

# %%
# Combine samples into one DataFrame for easier inspection
sampled_reviews = pd.concat([positive_samples, neutral_samples, negative_samples])

# Display sampled reviews with TextBlob and VADER sentiment labels
print("Sampled Reviews for Sentiment Analysis:")
print(sampled_reviews[['review_content', 'textblob_sentiment', 'vader_sentiment']])

# Save results to CSV for inspection
reviews_df[['review_content', 'rating', 'rating_sentiment', 'vader_sentiment', 'textblob_sentiment']].to_csv('sentiment_comparison.csv', index=False)
print("Results saved to 'sentiment_comparison.csv'.")
# Out:
# Sampled Reviews for Sentiment Analysis:
#                                         review_content textblob_sentiment  \
# 745  flew wellingtonsan francisco via auckland boug...           Positive
# 181  auckland to sydney in february 2020 it was gre...           Positive
# 57                                        not verified            Neutral
# 161  i paid the works for my daughter when i booked...            Neutral
# 172  unfortunately i left my phone wallet behind so...           Negative
# 152  a quick back story my wife and myself were mov...           Negative
#
#     vader_sentiment
# 745        Positive
# 181        Positive
# 57          Neutral
# 161         Neutral
# 172        Positive
# 152        Positive
# Results saved to 'sentiment_comparison.csv'.

# %%
# Calculate confusion matrix and classification report for VADER
y_true = reviews_df['rating_sentiment']
y_pred_vader = reviews_df['vader_sentiment']

conf_matrix_vader = confusion_matrix(y_true, y_pred_vader, labels=['Positive', 'Neutral', 'Negative'])
class_report_vader = classification_report(y_true, y_pred_vader, labels=['Positive', 'Neutral', 'Negative'])

print("Confusion Matrix for VADER:")
print(conf_matrix_vader)
print("\nClassification Report for VADER:")
print(class_report_vader)
# Out:
# Confusion Matrix for VADER:
# [[267   1   5]
#  [102   6  47]
#  [ 88   4 229]]
#
# Classification Report for VADER:
#               precision    recall  f1-score   support
#
#     Positive       0.58      0.98      0.73       273
#      Neutral       0.55      0.04      0.07       155
#     Negative       0.81      0.71      0.76       321
#
#     accuracy                           0.67       749
#    macro avg       0.65      0.58      0.52       749
# weighted avg       0.68      0.67      0.61       749

# %%
# Calculate confusion matrix and classification report for TextBlob
y_pred_textblob = reviews_df['textblob_sentiment']

conf_matrix_textblob = confusion_matrix(y_true, y_pred_textblob, labels=['Positive', 'Neutral', 'Negative'])
class_report_textblob = classification_report(y_true, y_pred_textblob, labels=['Positive', 'Neutral', 'Negative'])

print("Confusion Matrix for TextBlob:")
print(conf_matrix_textblob)
print("\nClassification Report for TextBlob:")
print(class_report_textblob)
# Out:
# Confusion Matrix for TextBlob:
# [[269   0   4]
#  [128   0  27]
#  [143   3 175]]
#
# Classification Report for TextBlob:
#               precision    recall  f1-score   support
#
#     Positive       0.50      0.99      0.66       273
#      Neutral       0.00      0.00      0.00       155
#     Negative       0.85      0.55      0.66       321
#
#     accuracy                           0.59       749
#    macro avg       0.45      0.51      0.44       749
# weighted avg       0.55      0.59      0.53       749

# %%
# Save results to CSV for inspection
reviews_df[['review_content', 'rating', 'rating_sentiment', 'vader_sentiment', 'textblob_sentiment']].to_csv('sentiment_comparison.csv', index=False)
print("Results saved to 'sentiment_comparison.csv'.")

# Plot confusion matrices
def plot_confusion_matrix(cm, labels, title):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Sentiment', fontsize=14, fontweight='bold')
    plt.ylabel('True Sentiment', fontsize=14, fontweight='bold')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.show()

plot_confusion_matrix(conf_matrix_vader, labels=['Positive', 'Neutral', 'Negative'], title='Confusion Matrix for VADER')
plot_confusion_matrix(conf_matrix_textblob, labels=['Positive', 'Neutral', 'Negative'], title='Confusion Matrix for TextBlob')
# Out:
# Results saved to 'sentiment_comparison.csv'.

# %%
# Calculate accuracies
def calculate_accuracy(df, sentiment_col):
    return (df['rating_sentiment'] == df[sentiment_col]).mean()

vader_accuracy = calculate_accuracy(reviews_df, 'vader_sentiment')
textblob_accuracy = calculate_accuracy(reviews_df, 'textblob_sentiment')

print(f"VADER Accuracy: {vader_accuracy:.2f}")
print(f"TextBlob Accuracy: {textblob_accuracy:.2f}")
# Out:
# VADER Accuracy: 0.67
# TextBlob Accuracy: 0.59

# %%
accuracy_df = pd.DataFrame({
    'Tool': ['VADER', 'TextBlob'],
    'Accuracy': [vader_accuracy, textblob_accuracy]
})


plt.figure(figsize=(8, 5))
sns.barplot(x='Tool', y='Accuracy', data=accuracy_df, palette='viridis')
plt.ylim(0, 1)  
plt.xlabel('Sentiment Analysis Tool', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
plt.title('Accuracy of Sentiment Analysis Tools', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)


for index, value in enumerate(accuracy_df['Accuracy']):
    plt.text(index, value + 0.02, f'{value:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/1864585545.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tool', y='Accuracy', data=accuracy_df, palette='viridis')

# %%
# Convert 'date' to datetime and extract the year
reviews_df['year'] = pd.to_datetime(reviews_df['date'], format='%Y-%m-%d').dt.year

# Number of reviews aggregated by year and sentiment
sentiment_by_year = reviews_df.groupby(['year', 'vader_sentiment']).size().unstack(fill_value=0)

sentiment_by_year
# Out:
# vader_sentiment  Negative  Neutral  Positive
# year
# 2013                   17        0        59
# 2014                   19        0        67
# 2015                   14        1        54
# 2016                   18        0        56
# 2017                   19        1        50
# 2018                   32        2        44
# 2019                   49        0        32
# 2020                   26        2        17
# 2021                   15        1         9
# 2022                   23        1        28
# 2023                   35        3        31
# 2024                   14        0        10

# %%
reviews_df.to_csv("reviews_with_sentiments.csv", index=False)

# %% [markdown]
# # How do domestic & international routes compare in terms of review ratings?

# %%
import pandas as pd

cleaned_reviews = "reviews_with_sentiments.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  wifi_&_connectivity  \
# 0  December 2023           5.0                  5.0  ...                  4.0
# 1    August 2024           4.0                  5.0  ...                 -1.0
# 2      June 2024           3.0                  4.0  ...                 -1.0
# 3    August 2023           2.0                  3.0  ...                  1.0
# 4  December 2023           4.0                  5.0  ...                 -1.0
#
#    value_for_money  recommended  inflight_entertainment  verified_status  \
# 0              5.0         True                    -1.0            False
# 1              1.0        False                    -1.0            False
# 2              1.0        False                    -1.0             True
# 3              2.0        False                     2.0            False
# 4              5.0         True                    -1.0             True
#
#                                       review_content  textblob_sentiment  \
# 0  i was honestly quite surprised about air new z...            Positive
# 1  air new zealand domestic service is getting wo...            Negative
# 2  air new zealand bumped us off our flight on th...            Negative
# 3  very unfortunately the service care and qualit...            Negative
# 4  checkin was efficient boarding and departure w...            Positive
#
#   vader_sentiment rating_sentiment  year
# 0        Positive         Positive  2024
# 1        Negative         Negative  2024
# 2        Negative         Negative  2024
# 3        Negative         Negative  2024
# 4        Positive         Positive  2024
#
# [5 rows x 22 columns]

# %%
# Function to split the route into departure, arrival, and via
def split_route(route):
    # Check if the route is not NaN (missing value)
    if pd.isna(route):
        return pd.Series([None, None, None])
    
    # Split by "to" first
    if 'to' in route:
        departure, arrival_part = route.split(' to ', 1)
        
        # Check if "via" is present in the arrival part
        if 'via' in arrival_part:
            arrival, via = arrival_part.split(' via ', 1)
            return pd.Series([departure.strip(), arrival.strip(), via.strip()])
        else:
            return pd.Series([departure.strip(), arrival_part.strip(), None])
    else:
        return pd.Series([None, None, None])

reviews_df[['departure', 'arrival', 'via']] = reviews_df['route'].apply(split_route)

reviews_df[['route', 'departure', 'arrival', 'via']].head()
# Out:
#                                       route      departure     arrival  \
# 0                    Auckland to Queenstown       Auckland  Queenstown
# 1                        Auckland to Napier       Auckland      Napier
# 2                        Napier to Auckland         Napier    Auckland
# 3  San Francisco to Queenstown via Auckland  San Francisco  Queenstown
# 4                        Auckland to Hobart       Auckland      Hobart
#
#         via
# 0      None
# 1      None
# 2      None
# 3  Auckland
# 4      None

# %%
# Load the New Zealand airports dataset
nz_airports = "nz_airports.csv"
nz_airports_df = pd.read_csv(nz_airports)

nz_airports_df['Municipality'] = nz_airports_df['Municipality'].str.lower()
reviews_df['departure'] = reviews_df['departure'].str.lower()
reviews_df['arrival'] = reviews_df['arrival'].str.lower()

nz_airports_df[['Municipality', 'ISO_Country']].head()
# Out:
#    Municipality ISO_Country
# 0      auckland          NZ
# 1         taupo          NZ
# 2  christchurch          NZ
# 3        te one          NZ
# 4       dunedin          NZ

# %%
# Merge only departure first to test merging process
reviews_with_departure_country = reviews_df.merge(nz_airports_df[['Municipality', 'ISO_Country']], 
                                                  left_on='departure', 
                                                  right_on='Municipality', 
                                                  how='left')

# Rename the iso_country column to departure_country
reviews_with_departure_country = reviews_with_departure_country.rename(columns={'ISO_Country': 'departure_country'})

# Sample to verify
reviews_with_departure_country
# Out:
#             date                              header  rating aircraft  \
# 0     2024-08-29                the legroom was huge       9     A320
# 1     2024-08-19            getting worse by the day       3      NaN
# 2     2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3     2024-07-29             has been going downhill       1      NaN
# 4     2024-07-19  Cabin crew and aircraft were great      10    A320N
# ...          ...                                 ...     ...      ...
# 1311  2013-05-06     Air New Zealand customer review       5      NaN
# 1312  2013-05-01     Air New Zealand customer review       5      NaN
# 1313  2013-05-01     Air New Zealand customer review       5      NaN
# 1314  2013-05-01     Air New Zealand customer review       5      NaN
# 1315  2013-05-01     Air New Zealand customer review       5      NaN
#
#      type_of_traveller        seat_type  \
# 0       Family Leisure    Economy Class
# 1             Business    Economy Class
# 2       Family Leisure    Economy Class
# 3         Solo Leisure   Business Class
# 4         Solo Leisure    Economy Class
# ...                ...              ...
# 1311               NaN    Economy Class
# 1312               NaN  Premium Economy
# 1313               NaN  Premium Economy
# 1314               NaN  Premium Economy
# 1315               NaN  Premium Economy
#
#                                          route     date_flown  seat_comfort  \
# 0                       Auckland to Queenstown  December 2023           5.0
# 1                           Auckland to Napier    August 2024           4.0
# 2                           Napier to Auckland      June 2024           3.0
# 3     San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                           Auckland to Hobart  December 2023           4.0
# ...                                        ...            ...           ...
# 1311                                       NaN            NaN           3.0
# 1312                                       NaN            NaN           3.0
# 1313                                       NaN            NaN           3.0
# 1314                                       NaN            NaN           3.0
# 1315                                       NaN            NaN           3.0
#
#       cabin_staff_service  ...  \
# 0                     5.0  ...
# 1                     5.0  ...
# 2                     4.0  ...
# 3                     3.0  ...
# 4                     5.0  ...
# ...                   ...  ...
# 1311                  3.0  ...
# 1312                  3.0  ...
# 1313                  3.0  ...
# 1314                  3.0  ...
# 1315                  3.0  ...
#
#                                          review_content  textblob_sentiment  \
# 0     i was honestly quite surprised about air new z...            Positive
# 1     air new zealand domestic service is getting wo...            Negative
# 2     air new zealand bumped us off our flight on th...            Negative
# 3     very unfortunately the service care and qualit...            Negative
# 4     checkin was efficient boarding and departure w...            Positive
# ...                                                 ...                 ...
# 1311  adelaide to auckland april 28 2013 usual incre...            Positive
# 1312  b747400 premium economy sfoakl b767 works akls...            Negative
# 1313  b747400 premium economy sfoakl b767 works akls...            Negative
# 1314  b747400 premium economy sfoakl b767 works akls...            Negative
# 1315  b747400 premium economy sfoakl b767 works akls...            Negative
#
#       vader_sentiment  rating_sentiment  year      departure     arrival  \
# 0            Positive          Positive  2024       auckland  queenstown
# 1            Negative          Negative  2024       auckland      napier
# 2            Negative          Negative  2024         napier    auckland
# 3            Negative          Negative  2024  san francisco  queenstown
# 4            Positive          Positive  2024       auckland      hobart
# ...               ...               ...   ...            ...         ...
# 1311         Positive           Neutral  2013           None        None
# 1312         Positive           Neutral  2013           None        None
# 1313         Positive           Neutral  2013           None        None
# 1314         Positive           Neutral  2013           None        None
# 1315         Positive           Neutral  2013           None        None
#
#            via Municipality departure_country
# 0         None     auckland                NZ
# 1         None     auckland                NZ
# 2         None       napier                NZ
# 3     Auckland          NaN               NaN
# 4         None     auckland                NZ
# ...        ...          ...               ...
# 1311      None          NaN                NZ
# 1312      None          NaN                NZ
# 1313      None          NaN                NZ
# 1314      None          NaN                NZ
# 1315      None          NaN                NZ
#
# [1316 rows x 27 columns]

# %%
# Now merge arrival country
reviews_with_full_country = reviews_with_departure_country.merge(nz_airports_df[['Municipality', 'ISO_Country']], 
                                                                 left_on='arrival', 
                                                                 right_on='Municipality', 
                                                                 how='left')

# Rename the iso_country column to arrival_country
reviews_with_full_country = reviews_with_full_country.rename(columns={'ISO_Country': 'arrival_country'})

# Verify the merge
print(reviews_with_full_country[['arrival', 'arrival_country']].head())
# Out:
#       arrival arrival_country
# 0  queenstown              NZ
# 1      napier              NZ
# 2    auckland              NZ
# 3  queenstown              NZ
# 4      hobart             NaN

# %%
reviews_with_full_country['departure_country'] = reviews_with_full_country.apply(
    lambda row: row['departure_country'] if pd.notna(row['departure']) else None, axis=1
)
reviews_with_full_country['arrival_country'] = reviews_with_full_country.apply(
    lambda row: row['arrival_country'] if pd.notna(row['arrival']) else None, axis=1
)

reviews_with_full_country
# Out:
#             date                              header  rating aircraft  \
# 0     2024-08-29                the legroom was huge       9     A320
# 1     2024-08-19            getting worse by the day       3      NaN
# 2     2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3     2024-07-29             has been going downhill       1      NaN
# 4     2024-07-19  Cabin crew and aircraft were great      10    A320N
# ...          ...                                 ...     ...      ...
# 3579  2013-05-01     Air New Zealand customer review       5      NaN
# 3580  2013-05-01     Air New Zealand customer review       5      NaN
# 3581  2013-05-01     Air New Zealand customer review       5      NaN
# 3582  2013-05-01     Air New Zealand customer review       5      NaN
# 3583  2013-05-01     Air New Zealand customer review       5      NaN
#
#      type_of_traveller        seat_type  \
# 0       Family Leisure    Economy Class
# 1             Business    Economy Class
# 2       Family Leisure    Economy Class
# 3         Solo Leisure   Business Class
# 4         Solo Leisure    Economy Class
# ...                ...              ...
# 3579               NaN  Premium Economy
# 3580               NaN  Premium Economy
# 3581               NaN  Premium Economy
# 3582               NaN  Premium Economy
# 3583               NaN  Premium Economy
#
#                                          route     date_flown  seat_comfort  \
# 0                       Auckland to Queenstown  December 2023           5.0
# 1                           Auckland to Napier    August 2024           4.0
# 2                           Napier to Auckland      June 2024           3.0
# 3     San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                           Auckland to Hobart  December 2023           4.0
# ...                                        ...            ...           ...
# 3579                                       NaN            NaN           3.0
# 3580                                       NaN            NaN           3.0
# 3581                                       NaN            NaN           3.0
# 3582                                       NaN            NaN           3.0
# 3583                                       NaN            NaN           3.0
#
#       cabin_staff_service  ...  vader_sentiment  rating_sentiment  year  \
# 0                     5.0  ...         Positive          Positive  2024
# 1                     5.0  ...         Negative          Negative  2024
# 2                     4.0  ...         Negative          Negative  2024
# 3                     3.0  ...         Negative          Negative  2024
# 4                     5.0  ...         Positive          Positive  2024
# ...                   ...  ...              ...               ...   ...
# 3579                  3.0  ...         Positive           Neutral  2013
# 3580                  3.0  ...         Positive           Neutral  2013
# 3581                  3.0  ...         Positive           Neutral  2013
# 3582                  3.0  ...         Positive           Neutral  2013
# 3583                  3.0  ...         Positive           Neutral  2013
#
#           departure     arrival       via  Municipality_x departure_country  \
# 0          auckland  queenstown      None        auckland                NZ
# 1          auckland      napier      None        auckland                NZ
# 2            napier    auckland      None          napier                NZ
# 3     san francisco  queenstown  Auckland             NaN               NaN
# 4          auckland      hobart      None        auckland                NZ
# ...             ...         ...       ...             ...               ...
# 3579           None        None      None             NaN              None
# 3580           None        None      None             NaN              None
# 3581           None        None      None             NaN              None
# 3582           None        None      None             NaN              None
# 3583           None        None      None             NaN              None
#
#      Municipality_y arrival_country
# 0        queenstown              NZ
# 1            napier              NZ
# 2          auckland              NZ
# 3        queenstown              NZ
# 4               NaN             NaN
# ...             ...             ...
# 3579            NaN            None
# 3580            NaN            None
# 3581            NaN            None
# 3582            NaN            None
# 3583            NaN            None
#
# [3584 rows x 29 columns]

# %%
duplicate_reviews = reviews_df[reviews_df.duplicated(subset=['review_content'], keep=False)]
print(duplicate_reviews)
# Out:
# Empty DataFrame
# Columns: [date, header, rating, aircraft, type_of_traveller, seat_type, route, date_flown, seat_comfort, cabin_staff_service, food_&_beverages, ground_service, wifi_&_connectivity, value_for_money, recommended, inflight_entertainment, verified_status, review_content, textblob_sentiment, vader_sentiment, rating_sentiment, year, departure, arrival, via]
# Index: []
#
# [0 rows x 25 columns]

# %%
reviews_df = reviews_df.drop_duplicates(subset=['review_content']) 

reviews_df
# Out:
#            date                              header  rating aircraft  \
# 0    2024-08-29                the legroom was huge       9     A320
# 1    2024-08-19            getting worse by the day       3      NaN
# 2    2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3    2024-07-29             has been going downhill       1      NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10    A320N
# ..          ...                                 ...     ...      ...
# 744  2013-05-12     Air New Zealand customer review       3      NaN
# 745  2013-05-10     Air New Zealand customer review      10      NaN
# 746  2013-05-08     Air New Zealand customer review       9      NaN
# 747  2013-05-06     Air New Zealand customer review       5      NaN
# 748  2013-05-01     Air New Zealand customer review       5      NaN
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 744               NaN    Economy Class
# 745               NaN  Premium Economy
# 746               NaN  Premium Economy
# 747               NaN    Economy Class
# 748               NaN  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 744                                       NaN            NaN           3.0
# 745                                       NaN            NaN           5.0
# 746                                       NaN            NaN           4.0
# 747                                       NaN            NaN           3.0
# 748                                       NaN            NaN           3.0
#
#      cabin_staff_service  ...  inflight_entertainment  verified_status  \
# 0                    5.0  ...                    -1.0            False
# 1                    5.0  ...                    -1.0            False
# 2                    4.0  ...                    -1.0             True
# 3                    3.0  ...                     2.0            False
# 4                    5.0  ...                    -1.0             True
# ..                   ...  ...                     ...              ...
# 744                  2.0  ...                     4.0            False
# 745                  5.0  ...                     5.0            False
# 746                  5.0  ...                     5.0            False
# 747                  3.0  ...                     1.0            False
# 748                  3.0  ...                     3.0            False
#
#                                         review_content  textblob_sentiment  \
# 0    i was honestly quite surprised about air new z...            Positive
# 1    air new zealand domestic service is getting wo...            Negative
# 2    air new zealand bumped us off our flight on th...            Negative
# 3    very unfortunately the service care and qualit...            Negative
# 4    checkin was efficient boarding and departure w...            Positive
# ..                                                 ...                 ...
# 744  i have flown with air new zealand for several ...            Positive
# 745  flew wellingtonsan francisco via auckland boug...            Positive
# 746  flew premium economy from lax to akl on a 7772...            Positive
# 747  adelaide to auckland april 28 2013 usual incre...            Positive
# 748  b747400 premium economy sfoakl b767 works akls...            Negative
#
#      vader_sentiment  rating_sentiment  year      departure     arrival  \
# 0           Positive          Positive  2024       auckland  queenstown
# 1           Negative          Negative  2024       auckland      napier
# 2           Negative          Negative  2024         napier    auckland
# 3           Negative          Negative  2024  san francisco  queenstown
# 4           Positive          Positive  2024       auckland      hobart
# ..               ...               ...   ...            ...         ...
# 744         Positive          Negative  2013           None        None
# 745         Positive          Positive  2013           None        None
# 746         Positive          Positive  2013           None        None
# 747         Positive           Neutral  2013           None        None
# 748         Positive           Neutral  2013           None        None
#
#           via
# 0        None
# 1        None
# 2        None
# 3    Auckland
# 4        None
# ..        ...
# 744      None
# 745      None
# 746      None
# 747      None
# 748      None
#
# [749 rows x 25 columns]

# %%
# Load general airports dataset
airports_df = pd.read_csv("airports.csv")

airports_df['municipality'] = airports_df['municipality'].str.lower()
airports_df['iata_code'] = airports_df['iata_code'].str.lower()

# Handle NaN departure_country
nan_departure_country = reviews_with_full_country[reviews_with_full_country['departure_country'].isna()]
nan_departure_municipalities = nan_departure_country['departure'].unique()

# Find corresponding ISO country from airports_df
nan_departure_countries = airports_df[airports_df['municipality'].isin(nan_departure_municipalities)]
municipality_to_country = dict(zip(nan_departure_countries['municipality'], nan_departure_countries['iso_country']))

# Update departure_country
reviews_with_full_country['departure_country'] = reviews_with_full_country['departure'].map(municipality_to_country).fillna(reviews_with_full_country['departure_country'])

# Handle NaN arrival_country similarly
nan_arrival_country = reviews_with_full_country[reviews_with_full_country['arrival_country'].isna()]
nan_arrival_municipalities = nan_arrival_country['arrival'].unique()

# Find corresponding ISO country for arrival
nan_arrival_countries = airports_df[airports_df['municipality'].isin(nan_arrival_municipalities)]
municipality_to_country = dict(zip(nan_arrival_countries['municipality'], nan_arrival_countries['iso_country']))

# Update arrival_country
reviews_with_full_country['arrival_country'] = reviews_with_full_country['arrival'].map(municipality_to_country).fillna(reviews_with_full_country['arrival_country'])
reviews_with_full_country
# Out:
#             date                              header  rating aircraft  \
# 0     2024-08-29                the legroom was huge       9     A320
# 1     2024-08-19            getting worse by the day       3      NaN
# 2     2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3     2024-07-29             has been going downhill       1      NaN
# 4     2024-07-19  Cabin crew and aircraft were great      10    A320N
# ...          ...                                 ...     ...      ...
# 3579  2013-05-01     Air New Zealand customer review       5      NaN
# 3580  2013-05-01     Air New Zealand customer review       5      NaN
# 3581  2013-05-01     Air New Zealand customer review       5      NaN
# 3582  2013-05-01     Air New Zealand customer review       5      NaN
# 3583  2013-05-01     Air New Zealand customer review       5      NaN
#
#      type_of_traveller        seat_type  \
# 0       Family Leisure    Economy Class
# 1             Business    Economy Class
# 2       Family Leisure    Economy Class
# 3         Solo Leisure   Business Class
# 4         Solo Leisure    Economy Class
# ...                ...              ...
# 3579               NaN  Premium Economy
# 3580               NaN  Premium Economy
# 3581               NaN  Premium Economy
# 3582               NaN  Premium Economy
# 3583               NaN  Premium Economy
#
#                                          route     date_flown  seat_comfort  \
# 0                       Auckland to Queenstown  December 2023           5.0
# 1                           Auckland to Napier    August 2024           4.0
# 2                           Napier to Auckland      June 2024           3.0
# 3     San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                           Auckland to Hobart  December 2023           4.0
# ...                                        ...            ...           ...
# 3579                                       NaN            NaN           3.0
# 3580                                       NaN            NaN           3.0
# 3581                                       NaN            NaN           3.0
# 3582                                       NaN            NaN           3.0
# 3583                                       NaN            NaN           3.0
#
#       cabin_staff_service  ...  vader_sentiment  rating_sentiment  year  \
# 0                     5.0  ...         Positive          Positive  2024
# 1                     5.0  ...         Negative          Negative  2024
# 2                     4.0  ...         Negative          Negative  2024
# 3                     3.0  ...         Negative          Negative  2024
# 4                     5.0  ...         Positive          Positive  2024
# ...                   ...  ...              ...               ...   ...
# 3579                  3.0  ...         Positive           Neutral  2013
# 3580                  3.0  ...         Positive           Neutral  2013
# 3581                  3.0  ...         Positive           Neutral  2013
# 3582                  3.0  ...         Positive           Neutral  2013
# 3583                  3.0  ...         Positive           Neutral  2013
#
#           departure     arrival       via  Municipality_x departure_country  \
# 0          auckland  queenstown      None        auckland                NZ
# 1          auckland      napier      None        auckland                NZ
# 2            napier    auckland      None          napier                NZ
# 3     san francisco  queenstown  Auckland             NaN                US
# 4          auckland      hobart      None        auckland                NZ
# ...             ...         ...       ...             ...               ...
# 3579           None        None      None             NaN              None
# 3580           None        None      None             NaN              None
# 3581           None        None      None             NaN              None
# 3582           None        None      None             NaN              None
# 3583           None        None      None             NaN              None
#
#      Municipality_y arrival_country
# 0        queenstown              NZ
# 1            napier              NZ
# 2          auckland              NZ
# 3        queenstown              NZ
# 4               NaN              AU
# ...             ...             ...
# 3579            NaN            None
# 3580            NaN            None
# 3581            NaN            None
# 3582            NaN            None
# 3583            NaN            None
#
# [3584 rows x 29 columns]

# %%
airports = "airports.csv"
airports_df = pd.read_csv(airports)

airports_df['municipality'] = airports_df['municipality'].str.lower()
airports_df['iata_code'] = airports_df['iata_code'].str.lower()

# %%
# Map IATA code to ISO country
iata_to_country = dict(zip(airports_df['iata_code'], airports_df['iso_country']))

# %%
# Function to get ISO country from IATA code
def get_country_from_iata(iata_code, mapping):
    return mapping.get(iata_code, None)

# Update 'departure_country' using the IATA code
reviews_with_full_country['departure_country'] = reviews_with_full_country.apply(
    lambda row: get_country_from_iata(row['departure'], iata_to_country) if pd.isna(row['departure_country']) and pd.notna(row['departure']) else row['departure_country'], axis=1
)

# Update 'arrival_country' using the IATA code
reviews_with_full_country['arrival_country'] = reviews_with_full_country.apply(
    lambda row: get_country_from_iata(row['arrival'], iata_to_country) if pd.isna(row['arrival_country']) and pd.notna(row['arrival']) else row['arrival_country'], axis=1
)

# %%
print(reviews_with_full_country[['departure', 'departure_country', 'arrival', 'arrival_country']].head())
# Out:
#        departure departure_country     arrival arrival_country
# 0       auckland                NZ  queenstown              NZ
# 1       auckland                NZ      napier              NZ
# 2         napier                NZ    auckland              NZ
# 3  san francisco                US  queenstown              NZ
# 4       auckland                NZ      hobart              AU

# %%
# Define the columns you want to keep
columns_to_keep = ['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
                    'seat_type', 'route', 'date_flown', 'seat_comfort',
                    'cabin_staff_service', 'food_&_beverages', 'ground_service',
                    'wifi_&_connectivity', 'value_for_money', 'recommended',
                    'inflight_entertainment', 'verified_status', 'review_content', 
                    'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
                    'departure', 'departure_country', 'arrival', 'arrival_country', 'via']

# Select only the necessary columns
nz_reviews_with_routes_df = reviews_with_full_country[columns_to_keep]

nz_reviews_with_routes_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  \
# 0  December 2023           5.0                  5.0  ...
# 1    August 2024           4.0                  5.0  ...
# 2      June 2024           3.0                  4.0  ...
# 3    August 2023           2.0                  3.0  ...
# 4  December 2023           4.0                  5.0  ...
#
#                                       review_content  textblob_sentiment  \
# 0  i was honestly quite surprised about air new z...            Positive
# 1  air new zealand domestic service is getting wo...            Negative
# 2  air new zealand bumped us off our flight on th...            Negative
# 3  very unfortunately the service care and qualit...            Negative
# 4  checkin was efficient boarding and departure w...            Positive
#
#    vader_sentiment  rating_sentiment  year      departure  departure_country  \
# 0         Positive          Positive  2024       auckland                 NZ
# 1         Negative          Negative  2024       auckland                 NZ
# 2         Negative          Negative  2024         napier                 NZ
# 3         Negative          Negative  2024  san francisco                 US
# 4         Positive          Positive  2024       auckland                 NZ
#
#       arrival arrival_country       via
# 0  queenstown              NZ      None
# 1      napier              NZ      None
# 2    auckland              NZ      None
# 3  queenstown              NZ  Auckland
# 4      hobart              AU      None
#
# [5 rows x 27 columns]

# %%
# Drop duplicates in the DataFrame
nz_reviews_with_routes_df = nz_reviews_with_routes_df.drop_duplicates()

# Drop rows where either 'departure' or 'arrival' is NaN
nz_reviews_with_routes_df = nz_reviews_with_routes_df.dropna(subset=['departure', 'arrival'])

nz_reviews_with_routes_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  \
# 0  December 2023           5.0                  5.0  ...
# 1    August 2024           4.0                  5.0  ...
# 2      June 2024           3.0                  4.0  ...
# 3    August 2023           2.0                  3.0  ...
# 4  December 2023           4.0                  5.0  ...
#
#                                       review_content  textblob_sentiment  \
# 0  i was honestly quite surprised about air new z...            Positive
# 1  air new zealand domestic service is getting wo...            Negative
# 2  air new zealand bumped us off our flight on th...            Negative
# 3  very unfortunately the service care and qualit...            Negative
# 4  checkin was efficient boarding and departure w...            Positive
#
#    vader_sentiment  rating_sentiment  year      departure  departure_country  \
# 0         Positive          Positive  2024       auckland                 NZ
# 1         Negative          Negative  2024       auckland                 NZ
# 2         Negative          Negative  2024         napier                 NZ
# 3         Negative          Negative  2024  san francisco                 US
# 4         Positive          Positive  2024       auckland                 NZ
#
#       arrival arrival_country       via
# 0  queenstown              NZ      None
# 1      napier              NZ      None
# 2    auckland              NZ      None
# 3  queenstown              NZ  Auckland
# 4      hobart              AU      None
#
# [5 rows x 27 columns]

# %%
# Filter rows where 'departure' or 'arrival' contains 'bne'
bne_reviews = nz_reviews_with_routes_df[(nz_reviews_with_routes_df['departure'] == 'bne') | (nz_reviews_with_routes_df['arrival'] == 'bne')]

bne_reviews
# Out:
#            date                              header  rating  \
# 470  2017-01-10     food very good and wine sublime      10
# 473  2017-01-01        Air New Zealand cost cutting       8
# 487  2016-11-22      never fly with Air New Zealand       1
# 490  2016-10-22      everything proved very average       6
# 501  2016-08-30  never travel Air New Zealand again       1
# 518  2016-06-25           crews were very attentive       9
# 533  2016-03-21              a very pleasant flight       8
# 538  2016-03-01      there are better options to US       5
# 590  2015-06-26     Air New Zealand customer review       9
#
#                  aircraft type_of_traveller       seat_type  \
# 470  Boeing777-300 / A320    Couple Leisure  Business Class
# 473                  A320      Solo Leisure   Economy Class
# 487                   NaN    Couple Leisure   Economy Class
# 490                  A320    Couple Leisure   Economy Class
# 501                   NaN    Family Leisure   Economy Class
# 518        Boeing 777-300          Business  Business Class
# 533            Boeing 777    Couple Leisure   Economy Class
# 538      Boeing 777-300ER    Couple Leisure   Economy Class
# 590               777-300          Business  Business Class
#
#                   route     date_flown  seat_comfort  cabin_staff_service  \
# 470  BNE to WLG via AKL   January 2017           5.0                  5.0
# 473          CHC to BNE   January 2017           4.0                  4.0
# 487          BNE to NLK  November 2016          -1.0                 -1.0
# 490          CHC to BNE   October 2016           3.0                  4.0
# 501          ZQN to BNE    August 2016           1.0                  1.0
# 518  BNE to SFO via AKL      June 2016           5.0                  5.0
# 533          BNE to AKL     March 2016           4.0                  5.0
# 538  BNE to LAX via AKL  February 2016           2.0                  4.0
# 590  LAX to BNE via AKL      June 2015           5.0                  5.0
#
#      ...                                     review_content  \
# 470  ...  brisbane to wellington via auckland the servic...
# 473  ...  nz805 christchurch to brisbane i consider this...
# 487  ...  my parents were flying brisbane to norfolk isl...
# 490  ...  flew christchurch to brisbane air new zealand ...
# 501  ...  i was absolutely shocked and disgusted to disc...
# 518  ...  brisbane to san francisco via auckland with ai...
# 533  ...  brisbane to auckland with air new zealand was ...
# 538  ...  brisbane to los angeles via auckland and the f...
# 590  ...  two wonderful flights with engaging and helpfu...
#
#      textblob_sentiment  vader_sentiment  rating_sentiment  year  departure  \
# 470            Positive         Positive          Positive  2017        bne
# 473            Positive         Positive          Positive  2017        chc
# 487            Negative         Positive          Negative  2016        bne
# 490            Positive         Positive           Neutral  2016        chc
# 501            Negative         Negative          Negative  2016        zqn
# 518            Positive         Negative          Positive  2016        bne
# 533            Positive         Positive          Positive  2016        bne
# 538            Positive         Positive           Neutral  2016        bne
# 590            Positive         Positive          Positive  2015        lax
#
#      departure_country arrival arrival_country   via
# 470                 AU     wlg              NZ   AKL
# 473                 NZ     bne              AU  None
# 487                 AU     nlk              NF  None
# 490                 NZ     bne              AU  None
# 501                 NZ     bne              AU  None
# 518                 AU     sfo              US   AKL
# 533                 AU     akl              NZ  None
# 538                 AU     lax              US   AKL
# 590                 US     bne              AU   AKL
#
# [9 rows x 27 columns]

# %%
# Determine if a route is domestic or international
nz_reviews_with_routes_df['is_domestic'] = (nz_reviews_with_routes_df['departure_country'] == 'NZ') & (nz_reviews_with_routes_df['arrival_country'] == 'NZ')

# Count domestic and international routes
route_counts = nz_reviews_with_routes_df['is_domestic'].value_counts()

# Prepare labels and values for plotting
labels = ['Domestic', 'International']
values = route_counts.values

# Print counts for verification
print(f"Domestic routes: {route_counts[True]}")
print(f"International routes: {route_counts[False]}")
# Out:
# Domestic routes: 114
# International routes: 446

# %%
# Pie chart for domestic and international routes
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['blue', 'orange'])
plt.title('Percentage of Domestic vs International Routes')
plt.show()

# %%
nz_reviews_with_routes_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content',
#        'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
#        'departure', 'departure_country', 'arrival', 'arrival_country', 'via',
#        'is_domestic'],
#       dtype='object')

# %%
# Inspect the dataset for missing values
nz_reviews_with_routes_df[rating_columns].isnull().sum()

# Check the distribution of domestic and international routes
nz_reviews_with_routes_df['is_domestic'].value_counts()
# Out:
# is_domestic
# False    446
# True     114
# Name: count, dtype: int64

# %%
# List of rating columns
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service',
                   'wifi_&_connectivity', 'value_for_money', 'inflight_entertainment']

# Calculate average ratings for each category by route type
average_ratings = nz_reviews_with_routes_df.groupby(['is_domestic'])[rating_columns].mean().reset_index()

# Display the average ratings
average_ratings
# Out:
#    is_domestic  seat_comfort  cabin_staff_service  food_&_beverages  \
# 0        False      2.778027             2.991031          2.345291
# 1         True      2.605263             2.903509          1.210526
#
#    ground_service  wifi_&_connectivity  value_for_money  \
# 0        2.773543             0.172646         2.746637
# 1        2.263158            -0.298246         2.377193
#
#    inflight_entertainment
# 0                2.609865
# 1               -0.105263

# %%
# Melt the DataFrame to long format
average_ratings_melted = average_ratings.melt(id_vars=['is_domestic'], 
                                              value_vars=rating_columns,
                                              var_name='category', 
                                              value_name='average_rating')

plt.figure(figsize=(14, 8))

sns.barplot(data=average_ratings_melted, x='category', y='average_rating', hue='is_domestic', palette='coolwarm')

plt.title('Average Ratings per Category: Domestic vs International Routes', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Average Rating', fontsize=14)
plt.xticks(rotation=45, ha='right')


handles, labels = plt.gca().get_legend_handles_labels()
new_labels = ['Domestic' if label == 'True' else 'International' for label in labels]
plt.legend(handles=handles, labels=new_labels, title='Route Type', title_fontsize='13', fontsize='12')

plt.tight_layout()
plt.show()

# %%
# Check average ratings for a specific category and route type
average_ratings.loc[average_ratings['is_domestic'] == 0, rating_columns]  # International
average_ratings.loc[average_ratings['is_domestic'] == 1, rating_columns]  # Domestic
# Out:
#    seat_comfort  cabin_staff_service  food_&_beverages  ground_service  \
# 1      2.605263             2.903509          1.210526        2.263158
#
#    wifi_&_connectivity  value_for_money  inflight_entertainment
# 1            -0.298246         2.377193               -0.105263

# %%
nz_reviews_with_routes_df.to_csv("nz_reviews_with_routes.csv", index=False)
nz_reviews_with_routes_df
# Out:
#            date                              header  rating        aircraft  \
# 0    2024-08-29                the legroom was huge       9            A320
# 1    2024-08-19            getting worse by the day       3             NaN
# 2    2024-08-13     never fly Air New Zealand again       1          ATR-72
# 3    2024-07-29             has been going downhill       1             NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10           A320N
# ..          ...                                 ...     ...             ...
# 587  2015-07-14     Air New Zealand customer review       4      Boeing 777
# 588  2015-07-03     Air New Zealand customer review       4        B777-300
# 589  2015-06-29     Air New Zealand customer review      10  Boeing 777-300
# 590  2015-06-26     Air New Zealand customer review       9         777-300
# 591  2015-06-15     Air New Zealand customer review       9  Boeing 777-300
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 587      Solo Leisure    Economy Class
# 588          Business    Economy Class
# 589      Solo Leisure   Business Class
# 590          Business   Business Class
# 591      Solo Leisure  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 587                     London to Los Angeles      June 2015           1.0
# 588                           Auckland to LAX      June 2015           2.0
# 589                   Los Angeles to Auckland      June 2015           5.0
# 590                        LAX to BNE via AKL      June 2015           5.0
# 591                   Los Angeles to Auckland      June 2015           5.0
#
#      cabin_staff_service  ...  textblob_sentiment  vader_sentiment  \
# 0                    5.0  ...            Positive         Positive
# 1                    5.0  ...            Negative         Negative
# 2                    4.0  ...            Negative         Negative
# 3                    3.0  ...            Negative         Negative
# 4                    5.0  ...            Positive         Positive
# ..                   ...  ...                 ...              ...
# 587                  2.0  ...            Positive         Positive
# 588                  4.0  ...            Positive         Positive
# 589                  5.0  ...            Positive         Positive
# 590                  5.0  ...            Positive         Positive
# 591                  5.0  ...            Positive         Positive
#
#      rating_sentiment  year      departure  departure_country      arrival  \
# 0            Positive  2024       auckland                 NZ   queenstown
# 1            Negative  2024       auckland                 NZ       napier
# 2            Negative  2024         napier                 NZ     auckland
# 3            Negative  2024  san francisco                 US   queenstown
# 4            Positive  2024       auckland                 NZ       hobart
# ..                ...   ...            ...                ...          ...
# 587           Neutral  2015         london                 US  los angeles
# 588           Neutral  2015       auckland                 NZ          lax
# 589          Positive  2015    los angeles                 US     auckland
# 590          Positive  2015            lax                 US          bne
# 591          Positive  2015    los angeles                 US     auckland
#
#     arrival_country       via is_domestic
# 0                NZ      None        True
# 1                NZ      None        True
# 2                NZ      None        True
# 3                NZ  Auckland       False
# 4                AU      None       False
# ..              ...       ...         ...
# 587              US      None       False
# 588              US      None       False
# 589              NZ      None       False
# 590              AU       AKL       False
# 591              NZ      None       False
#
# [560 rows x 28 columns]

# %% [markdown]
# # Do customer reviews improve over time?

# %%
# Convert 'date' to datetime and extract the year
reviews_df['year'] = pd.to_datetime(nz_reviews_with_routes_df['date'], format='%Y-%m-%d').dt.year

# Number of reviews aggregated by year and sentiment
sentiment_by_year = reviews_df.groupby(['year', 'vader_sentiment']).size().unstack(fill_value=0)

sentiment_by_year
# Out:
# vader_sentiment  Negative  Neutral  Positive
# year
# 2015.0                  1        0        11
# 2016.0                 15        0        59
# 2017.0                 17        1        52
# 2018.0                 33        2        43
# 2019.0                 44        0        37
# 2020.0                 23        1        21
# 2021.0                 15        1         9
# 2022.0                 27        1        24
# 2023.0                 34        1        33
# 2024.0                 11        2        10

# %%
from sklearn.linear_model import LinearRegression

# Convert years to a numpy array
years = sentiment_by_year.index.values.reshape(-1, 1)


plt.figure(figsize=(12, 8))

# Linear regression for each sentiment category
for sentiment in sentiment_by_year.columns:
    counts = sentiment_by_year[sentiment].values
    model = LinearRegression().fit(years, counts)
    trend_line = model.predict(years)
    plt.plot(years, trend_line, label=f'{sentiment} Trend', linestyle='--')

# Plot actual data
for sentiment in sentiment_by_year.columns:
    plt.plot(sentiment_by_year.index, sentiment_by_year[sentiment], marker='o', label=f'{sentiment} Actual')

plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Total Reviews by Year and Sentiment', fontsize=16, fontweight='bold')
plt.legend(title='Sentiment')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # What key themes emerge from Air New Zealand's customer reviews across different sentiments?

# %%
reviews_df = nz_reviews_with_routes_df
reviews_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  textblob_sentiment  \
# 0  December 2023           5.0                  5.0  ...            Positive
# 1    August 2024           4.0                  5.0  ...            Negative
# 2      June 2024           3.0                  4.0  ...            Negative
# 3    August 2023           2.0                  3.0  ...            Negative
# 4  December 2023           4.0                  5.0  ...            Positive
#
#    vader_sentiment  rating_sentiment  year      departure  departure_country  \
# 0         Positive          Positive  2024       auckland                 NZ
# 1         Negative          Negative  2024       auckland                 NZ
# 2         Negative          Negative  2024         napier                 NZ
# 3         Negative          Negative  2024  san francisco                 US
# 4         Positive          Positive  2024       auckland                 NZ
#
#       arrival arrival_country       via is_domestic
# 0  queenstown              NZ      None        True
# 1      napier              NZ      None        True
# 2    auckland              NZ      None        True
# 3  queenstown              NZ  Auckland       False
# 4      hobart              AU      None       False
#
# [5 rows x 28 columns]

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from collections import Counter
from nltk.util import ngrams
import re

# %%
# Initialize stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# Common words to exclude from analysis
excluded_terms = ["air_new_zealand", "flight", "auckland", "christchurch", "wellington", 
                  "new", "zealand", "air", "nz", "even_though", "via", "av", "sec"]

# Function to preprocess text
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = " ".join([lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words])
    return text

# Function to generate exactly 3-word n-grams and join words with underscores
def generate_ngrams(text, n=3):
    words = text.split()
    # Generate only 4-word n-grams
    ngrams_list = ["_".join(ngram) for ngram in ngrams(words, n)]
    return ngrams_list


# Function to get top N n-grams while excluding certain terms
def get_top_n_ngrams(sentiment_reviews, n=20):
    all_ngrams = []
    for review in sentiment_reviews:
        all_ngrams.extend(generate_ngrams(review)) 
    
    # Remove excluded terms
    filtered_ngrams = [ngram for ngram in all_ngrams if all(term not in ngram for term in excluded_terms)]
    
    # Count frequencies of remaining n-grams
    ngram_freq = Counter(filtered_ngrams)
    return ngram_freq.most_common(n)

# Preprocess the reviews
reviews_df['cleaned_review'] = reviews_df['review_content'].apply(preprocess_text)

# %%
# Get the top 10 n-grams for each sentiment
positive_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Positive']['cleaned_review']
negative_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Negative']['cleaned_review']
neutral_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Neutral']['cleaned_review']

top_positive_ngrams = get_top_n_ngrams(positive_reviews, 20)
top_negative_ngrams = get_top_n_ngrams(negative_reviews, 20)
top_neutral_ngrams = get_top_n_ngrams(neutral_reviews, 5)

# %%
# Function to plot the n-gram frequencies
def plot_ngram_frequencies(ngram_freq, title):
    ngrams, frequencies = zip(*ngram_freq)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.xlabel('Frequency', fontsize=14)
    plt.ylabel('N-grams', fontsize=14)
    plt.show()

# Plot the n-gram frequencies for each sentiment
plot_ngram_frequencies(top_positive_ngrams, 'Top 20 N-grams in Positive Reviews')
plot_ngram_frequencies(top_negative_ngrams, 'Top 20 N-grams in Negative Reviews')
plot_ngram_frequencies(top_neutral_ngrams, 'Top 5 N-grams in Neutral Reviews')
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')

# %%
from PIL import Image
from wordcloud import WordCloud

# %%
# Load the airplane mask image
mask = np.array(Image.open('/Users/ainna/Documents/Coding Crusade with Ainna/air-new-zealand-customer-feedback-analysis/airplane-vector-36294843 copy.jpg'))

# %%
def preprocess_ngrams(ngram_freq):
    # Split multi-word n-grams into individual words
    word_list = []
    for ngram, freq in ngram_freq.items():
        words = ngram.split('_')
        word_list.extend(words * freq)
    return Counter(word_list)

def plot_wordcloud(ngram_freq, title, mask):
    # Preprocess n-grams to individual words
    word_freq_dict = preprocess_ngrams(ngram_freq)
    
    # Create and generate the word cloud
    wc = WordCloud(width=800, height=400, background_color='white', colormap='viridis', mask=mask).generate_from_frequencies(word_freq_dict)
    
    # Plot the word cloud
    plt.figure(figsize=(10, 6))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.show()

# Plot the word clouds for each sentiment
plot_wordcloud(dict(top_positive_ngrams), 'Word Cloud for Positive Reviews', mask)
plot_wordcloud(dict(top_negative_ngrams), 'Word Cloud for Negative Reviews', mask)
plot_wordcloud(dict(top_neutral_ngrams), 'Word Cloud for Neutral Reviews', mask)

# %% [markdown]
# # Which type of traveler gives the highest/lowest ratings?

# %%
cleaned_reviews = "nz_reviews_with_routes.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  textblob_sentiment  \
# 0  December 2023           5.0                  5.0  ...            Positive
# 1    August 2024           4.0                  5.0  ...            Negative
# 2      June 2024           3.0                  4.0  ...            Negative
# 3    August 2023           2.0                  3.0  ...            Negative
# 4  December 2023           4.0                  5.0  ...            Positive
#
#    vader_sentiment  rating_sentiment  year      departure  departure_country  \
# 0         Positive          Positive  2024       auckland                 NZ
# 1         Negative          Negative  2024       auckland                 NZ
# 2         Negative          Negative  2024         napier                 NZ
# 3         Negative          Negative  2024  san francisco                 US
# 4         Positive          Positive  2024       auckland                 NZ
#
#       arrival arrival_country       via is_domestic
# 0  queenstown              NZ       NaN        True
# 1      napier              NZ       NaN        True
# 2    auckland              NZ       NaN        True
# 3  queenstown              NZ  Auckland       False
# 4      hobart              AU       NaN       False
#
# [5 rows x 28 columns]

# %%
reviews_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content',
#        'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
#        'departure', 'departure_country', 'arrival', 'arrival_country', 'via',
#        'is_domestic'],
#       dtype='object')

# %%
# Checking the unique types of travelers
reviews_df['type_of_traveller'].unique()

# Checking the distribution of ratings
reviews_df['rating'].describe()
# Out:
# count    560.000000
# mean       4.800000
# std        3.530496
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        9.000000
# max       10.000000
# Name: rating, dtype: float64

# %%
# Grouping by type of traveller and calculating mean and median ratings
traveller_rating_summary = reviews_df.groupby('type_of_traveller')['rating'].agg(['mean', 'median', 'count']).reset_index()

# Sorting to find the highest and lowest mean ratings
traveller_rating_summary = traveller_rating_summary.sort_values(by='mean', ascending=False)
traveller_rating_summary
# Out:
#   type_of_traveller      mean  median  count
# 3      Solo Leisure  5.035000     4.0    200
# 1    Couple Leisure  4.901639     4.0    183
# 0          Business  4.630952     3.0     84
# 2    Family Leisure  4.247312     3.0     93

# %%
labels = traveller_rating_summary['type_of_traveller']
average_ratings = traveller_rating_summary['mean']

plt.figure(figsize=(8, 8))
plt.pie(average_ratings, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("viridis"))
plt.title('Average Rating Distribution by Type of Traveler')
plt.axis('equal')
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
reviews_df
# Out:
#            date                              header  rating        aircraft  \
# 0    2024-08-29                the legroom was huge       9            A320
# 1    2024-08-19            getting worse by the day       3             NaN
# 2    2024-08-13     never fly Air New Zealand again       1          ATR-72
# 3    2024-07-29             has been going downhill       1             NaN
# 4    2024-07-19  Cabin crew and aircraft were great      10           A320N
# ..          ...                                 ...     ...             ...
# 555  2015-07-14     Air New Zealand customer review       4      Boeing 777
# 556  2015-07-03     Air New Zealand customer review       4        B777-300
# 557  2015-06-29     Air New Zealand customer review      10  Boeing 777-300
# 558  2015-06-26     Air New Zealand customer review       9         777-300
# 559  2015-06-15     Air New Zealand customer review       9  Boeing 777-300
#
#     type_of_traveller        seat_type  \
# 0      Family Leisure    Economy Class
# 1            Business    Economy Class
# 2      Family Leisure    Economy Class
# 3        Solo Leisure   Business Class
# 4        Solo Leisure    Economy Class
# ..                ...              ...
# 555      Solo Leisure    Economy Class
# 556          Business    Economy Class
# 557      Solo Leisure   Business Class
# 558          Business   Business Class
# 559      Solo Leisure  Premium Economy
#
#                                         route     date_flown  seat_comfort  \
# 0                      Auckland to Queenstown  December 2023           5.0
# 1                          Auckland to Napier    August 2024           4.0
# 2                          Napier to Auckland      June 2024           3.0
# 3    San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                          Auckland to Hobart  December 2023           4.0
# ..                                        ...            ...           ...
# 555                     London to Los Angeles      June 2015           1.0
# 556                           Auckland to LAX      June 2015           2.0
# 557                   Los Angeles to Auckland      June 2015           5.0
# 558                        LAX to BNE via AKL      June 2015           5.0
# 559                   Los Angeles to Auckland      June 2015           5.0
#
#      cabin_staff_service  ...  textblob_sentiment  vader_sentiment  \
# 0                    5.0  ...            Positive         Positive
# 1                    5.0  ...            Negative         Negative
# 2                    4.0  ...            Negative         Negative
# 3                    3.0  ...            Negative         Negative
# 4                    5.0  ...            Positive         Positive
# ..                   ...  ...                 ...              ...
# 555                  2.0  ...            Positive         Positive
# 556                  4.0  ...            Positive         Positive
# 557                  5.0  ...            Positive         Positive
# 558                  5.0  ...            Positive         Positive
# 559                  5.0  ...            Positive         Positive
#
#      rating_sentiment  year      departure  departure_country      arrival  \
# 0            Positive  2024       auckland                 NZ   queenstown
# 1            Negative  2024       auckland                 NZ       napier
# 2            Negative  2024         napier                 NZ     auckland
# 3            Negative  2024  san francisco                 US   queenstown
# 4            Positive  2024       auckland                 NZ       hobart
# ..                ...   ...            ...                ...          ...
# 555           Neutral  2015         london                 US  los angeles
# 556           Neutral  2015       auckland                 NZ          lax
# 557          Positive  2015    los angeles                 US     auckland
# 558          Positive  2015            lax                 US          bne
# 559          Positive  2015    los angeles                 US     auckland
#
#     arrival_country       via is_domestic
# 0                NZ       NaN        True
# 1                NZ       NaN        True
# 2                NZ       NaN        True
# 3                NZ  Auckland       False
# 4                AU       NaN       False
# ..              ...       ...         ...
# 555              US       NaN       False
# 556              US       NaN       False
# 557              NZ       NaN       False
# 558              AU       AKL       False
# 559              NZ       NaN       False
#
# [560 rows x 28 columns]

# %%
# Group by type of traveler and sentiment label
sentiment_distribution = reviews_df.groupby(['type_of_traveller', 'vader_sentiment']).size().unstack(fill_value=0)

# Normalize to get percentage distribution
sentiment_distribution_percentage = sentiment_distribution.div(sentiment_distribution.sum(axis=1), axis=0)

# Display the sentiment distribution as a percentage
sentiment_distribution_percentage
# Out:
# vader_sentiment    Negative   Neutral  Positive
# type_of_traveller
# Business           0.392857  0.000000  0.607143
# Couple Leisure     0.442623  0.016393  0.540984
# Family Leisure     0.483871  0.032258  0.483871
# Solo Leisure       0.390000  0.020000  0.590000

# %%
traveller_types = sentiment_distribution.index

fig, axes = plt.subplots(1, len(traveller_types), figsize=(18, 6))

colors = ['#ff9999','#66b3ff','#99ff99']

# Iterate through each type of traveler and create a pie chart
for i, traveller_type in enumerate(traveller_types):
    sentiments = sentiment_distribution.loc[traveller_type]
    
    axes[i].pie(sentiments, labels=sentiments.index, autopct='%1.1f%%', startangle=90, colors=colors)
    
    axes[i].set_title(traveller_type)

plt.tight_layout()
plt.suptitle('Sentiment Distribution for Different Types of Travelers', y=1.05, fontsize=16)
plt.show()

# %% [markdown]
# # How do ratings vary by Seat Type (e.g. Economy, Business)?

# %%
# Group by seat type and calculate rating statistics
seat_rating_summary = reviews_df.groupby('seat_type')['rating'].agg(['mean', 'median', 'count']).reset_index()

# Sort the values to see which seat types have the highest/lowest ratings
seat_rating_summary = seat_rating_summary.sort_values(by='mean', ascending=False)

# Display the summary
seat_rating_summary
# Out:
#          seat_type      mean  median  count
# 0   Business Class  6.697674     8.0     86
# 2  Premium Economy  5.957447     8.0     47
# 1    Economy Class  4.290398     3.0    427

# %%
# Set the figure size for better readability
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the mean ratings by seat type
sns.barplot(x='seat_type', y='mean', data=seat_rating_summary, palette='coolwarm')

# Add labels and title
plt.title('Average Ratings by Seat Type')
plt.xlabel('Seat Type')
plt.ylabel('Average Rating')

# Display the plot
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/768762854.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y='mean', data=seat_rating_summary, palette='coolwarm')

# %%
# Set the figure size for better readability
plt.figure(figsize=(12, 6))

# Create a count plot to visualize the number of reviews for each rating per seat type
sns.countplot(x='rating', hue='seat_type', data=reviews_df, palette='coolwarm')

# Add labels and title
plt.title('Rating Distribution by Seat Type')
plt.xlabel('Rating') 
plt.ylabel('Count of Reviews')

# Display the plot
plt.show()

# %%
# List of rating columns excluding 'wifi_&_connectivity'
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service', 'value_for_money', 'wifi_&_connectivity', 'inflight_entertainment']

# %%
# Group by seat type and calculate the mean ratings for the selected columns
category_rating_summary = reviews_df.groupby('seat_type')[rating_columns].mean().reset_index()

# Display the summary
category_rating_summary
# Out:
#          seat_type  seat_comfort  cabin_staff_service  food_&_beverages  \
# 0   Business Class      3.616279             4.058140          3.593023
# 1    Economy Class      2.501171             2.707260          1.723653
# 2  Premium Economy      3.340426             3.404255          2.957447
#
#    ground_service  value_for_money  wifi_&_connectivity  \
# 0        3.290698         3.430233             0.255814
# 1        2.468384         2.454333             0.021077
# 2        3.361702         3.255319             0.255319
#
#    inflight_entertainment
# 0                3.255814
# 1                1.709602
# 2                3.021277

# %%
# Set the figure size for better readability
plt.figure(figsize=(14, 12))  # Adjusted size to fit all subplots

# Loop through each rating column and create a subplot
for i, column in enumerate(rating_columns):
    plt.subplot(4, 2, i+1)  # Create a 4x2 grid for subplots
    
    # Create a bar plot for the current category
    sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
    
    # Add title and labels
    plt.title(f'Average {column.replace("_", " ").title()} by Seat Type')
    plt.xlabel('Seat Type')
    plt.ylabel(f'Average {column.replace("_", " ").title()}')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')

# %% [markdown]
# # How do customer sentiments vary across different regions and flight routes?

# %%
reviews_df = pd.read_csv('nz_reviews_with_routes.csv')
reviews_df.head()
# Out:
#          date                              header  rating aircraft  \
# 0  2024-08-29                the legroom was huge       9     A320
# 1  2024-08-19            getting worse by the day       3      NaN
# 2  2024-08-13     never fly Air New Zealand again       1   ATR-72
# 3  2024-07-29             has been going downhill       1      NaN
# 4  2024-07-19  Cabin crew and aircraft were great      10    A320N
#
#   type_of_traveller       seat_type                                     route  \
# 0    Family Leisure   Economy Class                    Auckland to Queenstown
# 1          Business   Economy Class                        Auckland to Napier
# 2    Family Leisure   Economy Class                        Napier to Auckland
# 3      Solo Leisure  Business Class  San Francisco to Queenstown via Auckland
# 4      Solo Leisure   Economy Class                        Auckland to Hobart
#
#       date_flown  seat_comfort  cabin_staff_service  ...  textblob_sentiment  \
# 0  December 2023           5.0                  5.0  ...            Positive
# 1    August 2024           4.0                  5.0  ...            Negative
# 2      June 2024           3.0                  4.0  ...            Negative
# 3    August 2023           2.0                  3.0  ...            Negative
# 4  December 2023           4.0                  5.0  ...            Positive
#
#    vader_sentiment  rating_sentiment  year      departure  departure_country  \
# 0         Positive          Positive  2024       auckland                 NZ
# 1         Negative          Negative  2024       auckland                 NZ
# 2         Negative          Negative  2024         napier                 NZ
# 3         Negative          Negative  2024  san francisco                 US
# 4         Positive          Positive  2024       auckland                 NZ
#
#       arrival arrival_country       via is_domestic
# 0  queenstown              NZ       NaN        True
# 1      napier              NZ       NaN        True
# 2    auckland              NZ       NaN        True
# 3  queenstown              NZ  Auckland       False
# 4      hobart              AU       NaN       False
#
# [5 rows x 28 columns]

# %%
reviews_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content',
#        'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
#        'departure', 'departure_country', 'arrival', 'arrival_country', 'via',
#        'is_domestic'],
#       dtype='object')

# %%
from datetime import datetime

# Get the current year
current_year = datetime.now().year

# Filter the data for the current year
current_year_df = reviews_df[reviews_df['year'] == current_year]

# %%
# Mapping vader_sentiment to numerical values
sentiment_mapping = {'Negative': -1.0, 'Neutral': 0.0, 'Positive': 1.0}
current_year_df['vader_sentiment_numeric'] = current_year_df['vader_sentiment'].map(sentiment_mapping)
current_year_df
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/2418176807.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_year_df['vader_sentiment_numeric'] = current_year_df['vader_sentiment'].map(sentiment_mapping)
#           date                                      header  rating  \
# 0   2024-08-29                        the legroom was huge       9
# 1   2024-08-19                    getting worse by the day       3
# 2   2024-08-13             never fly Air New Zealand again       1
# 3   2024-07-29                     has been going downhill       1
# 4   2024-07-19          Cabin crew and aircraft were great      10
# 5   2024-06-25           professional and very sympathetic      10
# 6   2024-06-22                         Absolutely hopeless       1
# 7   2024-06-11               they still withdrew the funds       2
# 8   2024-06-09  not a single aspect this airline does well       1
# 9   2024-05-18                         an airline to avoid       3
# 10  2024-05-17                  Highly unreliable schedule       1
# 11  2024-05-17           Seat was spacious and comfortable       8
# 12  2024-05-12          Air hostess totally ignored myself       5
# 13  2024-05-12               treated me very disrespectful       6
# 14  2024-05-04                slightly unpleasant oddness"       6
# 15  2024-04-09            suggest avoiding Air New Zealand       1
# 16  2024-03-22                  Never fly with them again!       1
# 17  2024-02-04                        A comfortable flight       9
# 18  2024-01-29                          Poor communication       2
# 19  2024-01-28               An incredibly painful process       3
# 20  2024-01-18                     again I am disappointed       3
# 21  2024-01-15          flight credit rather than a refund       1
# 22  2024-01-15                customer service was abysmal       1
#
#              aircraft type_of_traveller        seat_type  \
# 0                A320    Family Leisure    Economy Class
# 1                 NaN          Business    Economy Class
# 2              ATR-72    Family Leisure    Economy Class
# 3                 NaN      Solo Leisure   Business Class
# 4               A320N      Solo Leisure    Economy Class
# 5                 NaN      Solo Leisure    Economy Class
# 6                 NaN      Solo Leisure   Business Class
# 7          Boeing 789      Solo Leisure    Economy Class
# 8                 NaN      Solo Leisure    Economy Class
# 9                 NaN          Business    Economy Class
# 10                NaN          Business    Economy Class
# 11         Boeing 787      Solo Leisure  Premium Economy
# 12         Boeing 787      Solo Leisure    Economy Class
# 13                NaN    Family Leisure    Economy Class
# 14  Boeing 777-300 ER          Business   Business Class
# 15                NaN    Couple Leisure    Economy Class
# 16               A330    Family Leisure    Economy Class
# 17                NaN    Couple Leisure    Economy Class
# 18                NaN      Solo Leisure    Economy Class
# 19                NaN    Couple Leisure    Economy Class
# 20                NaN    Family Leisure    Economy Class
# 21                NaN      Solo Leisure    Economy Class
# 22                NaN    Family Leisure    Economy Class
#
#                                        route     date_flown  seat_comfort  \
# 0                     Auckland to Queenstown  December 2023           5.0
# 1                         Auckland to Napier    August 2024           4.0
# 2                         Napier to Auckland      June 2024           3.0
# 3   San Francisco to Queenstown via Auckland    August 2023           2.0
# 4                         Auckland to Hobart  December 2023           4.0
# 5           Dunedin to Brisbane via Auckland      June 2024           3.0
# 6                       Auckland to Kerikeri      June 2024           2.0
# 7                         Auckland to Tahiti      June 2024           5.0
# 8                         Auckland to Sydney      June 2024           2.0
# 9                     Gold Coast to Auckland       May 2024           3.0
# 10                     Auckland to Melbourne       May 2024           3.0
# 11                         Tokyo to Auckland       May 2024           4.0
# 12                 Denpasar Bali to Auckland     March 2024           4.0
# 13                     Singapore to Auckland       May 2024           3.0
# 14        Sydney to Los Angeles via Auckland       May 2024           4.0
# 15                     Auckland to Melbourne     March 2024           2.0
# 16                    Sydney to Christchurch     March 2024           2.0
# 17          Rarotonga to Sydney via Auckland  February 2024           5.0
# 18                     Melbourne to Auckland   January 2024           3.0
# 19               Christchurch to Los Angeles  December 2023           3.0
# 20                         Auckland to Tokyo   January 2024           2.0
# 21                    Brisbane to Queenstown  February 2023          -1.0
# 22                      Auckland to GIsborne   January 2024           1.0
#
#     cabin_staff_service  ...  vader_sentiment  rating_sentiment  year  \
# 0                   5.0  ...         Positive          Positive  2024
# 1                   5.0  ...         Negative          Negative  2024
# 2                   4.0  ...         Negative          Negative  2024
# 3                   3.0  ...         Negative          Negative  2024
# 4                   5.0  ...         Positive          Positive  2024
# 5                   3.0  ...         Positive          Positive  2024
# 6                   2.0  ...         Positive          Negative  2024
# 7                   5.0  ...         Negative          Negative  2024
# 8                   2.0  ...         Positive          Negative  2024
# 9                   1.0  ...         Positive          Negative  2024
# 10                  2.0  ...         Negative          Negative  2024
# 11                  4.0  ...         Positive          Positive  2024
# 12                  1.0  ...         Negative           Neutral  2024
# 13                  1.0  ...         Negative           Neutral  2024
# 14                  3.0  ...         Positive           Neutral  2024
# 15                  1.0  ...         Negative          Negative  2024
# 16                  1.0  ...         Negative          Negative  2024
# 17                  5.0  ...         Positive          Positive  2024
# 18                  4.0  ...         Negative          Negative  2024
# 19                  4.0  ...         Negative          Negative  2024
# 20                  2.0  ...         Negative          Negative  2024
# 21                 -1.0  ...         Positive          Negative  2024
# 22                  2.0  ...         Negative          Negative  2024
#
#         departure  departure_country       arrival  arrival_country       via  \
# 0        auckland                 NZ    queenstown               NZ       NaN
# 1        auckland                 NZ        napier               NZ       NaN
# 2          napier                 NZ      auckland               NZ       NaN
# 3   san francisco                 US    queenstown               NZ  Auckland
# 4        auckland                 NZ        hobart               AU       NaN
# 5         dunedin                 NZ      brisbane               AU  Auckland
# 6        auckland                 NZ      kerikeri               NZ       NaN
# 7        auckland                 NZ        tahiti              NaN       NaN
# 8        auckland                 NZ        sydney               AU       NaN
# 9      gold coast                 AU      auckland               NZ       NaN
# 10       auckland                 NZ     melbourne               AU       NaN
# 11          tokyo                 JP      auckland               NZ       NaN
# 12  denpasar bali                NaN      auckland               NZ       NaN
# 13      singapore                 SG      auckland               NZ       NaN
# 14         sydney                 AU   los angeles               US  Auckland
# 15       auckland                 NZ     melbourne               AU       NaN
# 16         sydney                 AU  christchurch               NZ       NaN
# 17      rarotonga                NaN        sydney               AU  Auckland
# 18      melbourne                 AU      auckland               NZ       NaN
# 19   christchurch                 NZ   los angeles               US       NaN
# 20       auckland                 NZ         tokyo               JP       NaN
# 21       brisbane                 AU    queenstown               NZ       NaN
# 22       auckland                 NZ      gisborne               NZ       NaN
#
#    is_domestic vader_sentiment_numeric
# 0         True                     1.0
# 1         True                    -1.0
# 2         True                    -1.0
# 3        False                    -1.0
# 4        False                     1.0
# 5        False                     1.0
# 6         True                     1.0
# 7        False                    -1.0
# 8        False                     1.0
# 9        False                     1.0
# 10       False                    -1.0
# 11       False                     1.0
# 12       False                    -1.0
# 13       False                    -1.0
# 14       False                     1.0
# 15       False                    -1.0
# 16       False                    -1.0
# 17       False                     1.0
# 18       False                    -1.0
# 19       False                    -1.0
# 20       False                    -1.0
# 21       False                     1.0
# 22        True                    -1.0
#
# [23 rows x 29 columns]

# %%
# Domestic and International routes
domestic_routes = current_year_df[current_year_df['is_domestic'] == True]
international_routes = current_year_df[current_year_df['is_domestic'] == False]

# Calculate the mean sentiment per route
domestic_mean_sentiment = domestic_routes.groupby('route')['vader_sentiment_numeric'].mean().reset_index()
international_mean_sentiment = international_routes.groupby('route')['vader_sentiment_numeric'].mean().reset_index()

# Sort by mean sentiment in descending order (best routes at the top)
domestic_mean_sentiment_sorted = domestic_mean_sentiment.sort_values(by='vader_sentiment_numeric', ascending=False)
international_mean_sentiment_sorted = international_mean_sentiment.sort_values(by='vader_sentiment_numeric', ascending=False)

# %%
# Function to map color based on sentiment value
def get_color(sentiment_value):
    if sentiment_value > 0:
        return 'green'
    else:
        return 'orange'  # amber for negative and neutral

# Apply color mapping
domestic_mean_sentiment_sorted['color'] = domestic_mean_sentiment_sorted['vader_sentiment_numeric'].apply(get_color)
international_mean_sentiment_sorted['color'] = international_mean_sentiment_sorted['vader_sentiment_numeric'].apply(get_color)

# Extract color lists for domestic and international routes
domestic_colors = domestic_mean_sentiment_sorted['color'].tolist()
international_colors = international_mean_sentiment_sorted['color'].tolist()

# %%
# Plot domestic routes
plt.figure(figsize=(10, 6))
sns.barplot(x='vader_sentiment_numeric', y='route', data=domestic_mean_sentiment_sorted, palette=domestic_colors)
plt.title("Domestic Routes with Best and Worst Customer Experience")
plt.xlabel("Mean Sentiment")
plt.ylabel("Route")
plt.tight_layout()
plt.show()

# Plot international routes
plt.figure(figsize=(10, 6))
sns.barplot(x='vader_sentiment_numeric', y='route', data=international_mean_sentiment_sorted, palette=international_colors)
plt.title("International Routes with Best and Worst Customer Experience")
plt.xlabel("Mean Sentiment")
plt.ylabel("Route")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3281941968.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='vader_sentiment_numeric', y='route', data=domestic_mean_sentiment_sorted, palette=domestic_colors)
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5480/3281941968.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='vader_sentiment_numeric', y='route', data=international_mean_sentiment_sorted, palette=international_colors)
