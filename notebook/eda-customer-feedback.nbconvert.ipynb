# %%
import pandas as pd
import numpy as np

cleaned_reviews = "../dataset/air_nz_cleaned_data.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  \
# 0             5.0                  5.0               5.0
# 1             3.0                  4.0               3.0
# 2             5.0                  5.0               5.0
# 3             4.0                  5.0              -1.0
# 4             3.0                  4.0              -1.0
# ..            ...                  ...               ...
# 746           3.0                  2.0               3.0
# 747           5.0                  5.0               5.0
# 748           4.0                  5.0               5.0
# 749           3.0                  3.0               4.0
# 750           3.0                  3.0               4.0
#
#      inflight_entertainment  ground_service  wifi_&_connectivity  \
# 0                       5.0             5.0                  5.0
# 1                       3.0             1.0                  4.0
# 2                      -1.0             5.0                  4.0
# 3                      -1.0             5.0                 -1.0
# 4                      -1.0             1.0                 -1.0
# ..                      ...             ...                  ...
# 746                     4.0            -1.0                 -1.0
# 747                     5.0            -1.0                 -1.0
# 748                     5.0            -1.0                 -1.0
# 749                     1.0            -1.0                 -1.0
# 750                     3.0            -1.0                 -1.0
#
#      value_for_money  recommended aircraft  verified_status  \
# 0                5.0         True      NaN            False
# 1                1.0        False      NaN            False
# 2                5.0         True     A320            False
# 3                1.0        False      NaN            False
# 4                1.0        False   ATR-72             True
# ..               ...          ...      ...              ...
# 746              2.0        False      NaN            False
# 747              4.0         True      NaN            False
# 748              5.0         True      NaN            False
# 749              3.0        False      NaN            False
# 750              2.0        False      NaN            False
#
#                                         review_content
# 0    Such a lovely experience! Service was so good ...
# 1    I recently had a highly disappointing experien...
# 2    I was honestly quite surprised about Air New Z...
# 3    Air New Zealand domestic service is getting wo...
# 4    Air New Zealand bumped us off our flight on th...
# ..                                                 ...
# 746  I have flown with Air New Zealand for several ...
# 747  Flew Wellington-San Francisco (via Auckland). ...
# 748  Flew Premium Economy from LAX to AKL on a 777-...
# 749  Adelaide to Auckland April 28 2013. Usual incr...
# 750  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
# [751 rows x 18 columns]

# %%
reviews_df.columns
# Out:
# Index(['date', 'header', 'rating', 'type_of_traveller', 'seat_type', 'route',
#        'date_flown', 'seat_comfort', 'cabin_staff_service', 'food_&_beverages',
#        'inflight_entertainment', 'ground_service', 'wifi_&_connectivity',
#        'value_for_money', 'recommended', 'aircraft', 'verified_status',
#        'review_content'],
#       dtype='object')

# %% [markdown]
# # What are the average ratings for specific service categories (e.g., seat comfort, cabin staff service, food & beverages, etc.)?

# %%
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service','wifi_&_connectivity','value_for_money','inflight_entertainment']

# Average rating for each category
average_ratings_by_category = reviews_df[rating_columns].mean()
print("Average Ratings by Category:")
print(average_ratings_by_category)
# Out:
# Average Ratings by Category:
# seat_comfort              2.934754
# cabin_staff_service       3.177097
# food_&_beverages          2.455393
# ground_service            1.747004
# wifi_&_connectivity      -0.182423
# value_for_money           2.857523
# inflight_entertainment    2.342210
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Round up aaverage rating per category
average_ratings_by_category = np.ceil(reviews_df[rating_columns].mean())

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x=average_ratings_by_category.index, y=average_ratings_by_category.values, palette="viridis")

plt.title("Average Rating per Category (Rounded Up)", fontsize=16)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45, ha='right')

for i in range(len(average_ratings_by_category)):
    bar_plot.text(i, average_ratings_by_category.values[i] + 0.1, str(int(average_ratings_by_category.values[i])), 
                  ha='center', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/3891546184.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x=average_ratings_by_category.index, y=average_ratings_by_category.values, palette="viridis")

# %% [markdown]
# # What is the average overall rating of Air New Zealand based on customer reviews?

# %%
# Ratings converted to numeric if they are in string format
reviews_df['rating'] = pd.to_numeric(reviews_df['rating'], errors='coerce')

# Overall average rating
average_rating = reviews_df['rating'].mean()
print(f"Average Rating: {average_rating:.2f}")
# Out:
# Average Rating: 5.24

# %%
labels = ['Average Rating', 'Remaining']
sizes = [average_rating, 10 - average_rating]
colors = ['#4caf50', '#f0f0f0']  

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(sizes, labels=labels, colors=colors, startangle=90, autopct='%1.1f%%',
       pctdistance=0.85, wedgeprops={'edgecolor': 'white', 'linewidth': 2})

centre_circle = plt.Circle((0, 0), 0.70, fc='white', linewidth=1.25)
ax.add_artist(centre_circle)

plt.title(f'Average Rating: {average_rating:.2f}/10', fontsize=18, color='#333', fontweight='bold')
plt.setp(ax.texts, fontweight='bold', color='#555', fontsize=12)
plt.show()

# %% [markdown]
# # How do missing WiFi & Connectivity Ratings affect the overall average rating?

# %%
# Plot distribution of 'wifi_&_connectivity' ratings
plt.figure(figsize=(10, 6))
sns.histplot(reviews_df['wifi_&_connectivity'], bins=20, kde=True, color="skyblue")
plt.title("Distribution of WiFi & Connectivity Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
# Count of -1.0 values in 'wifi_&_connectivity'
negative_count = (reviews_df['wifi_&_connectivity'] == -1.0).sum()
total_count = len(reviews_df)
print(f"Number of -1.0 ratings: {negative_count}")
print(f"Total number of ratings: {total_count}")
# Out:
# Number of -1.0 ratings: 574
# Total number of ratings: 751

# %%
# Filter out -1.0 values and calculate the mean
valid_wifi_ratings = reviews_df[reviews_df['wifi_&_connectivity'] != -1.0]['wifi_&_connectivity']
average_valid_wifi_rating = valid_wifi_ratings.mean()

print(f"Average WiFi & Connectivity Rating (excluding -1.0): {average_valid_wifi_rating}")
# Out:
# Average WiFi & Connectivity Rating (excluding -1.0): 2.468926553672316

# %%
# Data for comparison
average_ratings_comparison = pd.Series({
    'With -1.0': reviews_df['wifi_&_connectivity'].mean(),
    'Without -1.0': average_valid_wifi_rating
})

plt.figure(figsize=(8, 5))
sns.barplot(x=average_ratings_comparison.index, y=average_ratings_comparison.values, palette="viridis")
plt.title("Comparison of Average WiFi & Connectivity Rating")
plt.xlabel("Including/Excluding -1.0 Values")
plt.ylabel("Average Rating")
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/3117925003.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_ratings_comparison.index, y=average_ratings_comparison.values, palette="viridis")

# %% [markdown]
# # What is the overall sentiment distribution of the reviews?

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import confusion_matrix, classification_report

# %%
reviews_df = pd.read_csv('../dataset/air_nz_cleaned_data.csv')

# Check for and handle missing values
reviews_df.dropna(subset=['review_content'], inplace=True)

reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  \
# 0             5.0                  5.0               5.0
# 1             3.0                  4.0               3.0
# 2             5.0                  5.0               5.0
# 3             4.0                  5.0              -1.0
# 4             3.0                  4.0              -1.0
# ..            ...                  ...               ...
# 746           3.0                  2.0               3.0
# 747           5.0                  5.0               5.0
# 748           4.0                  5.0               5.0
# 749           3.0                  3.0               4.0
# 750           3.0                  3.0               4.0
#
#      inflight_entertainment  ground_service  wifi_&_connectivity  \
# 0                       5.0             5.0                  5.0
# 1                       3.0             1.0                  4.0
# 2                      -1.0             5.0                  4.0
# 3                      -1.0             5.0                 -1.0
# 4                      -1.0             1.0                 -1.0
# ..                      ...             ...                  ...
# 746                     4.0            -1.0                 -1.0
# 747                     5.0            -1.0                 -1.0
# 748                     5.0            -1.0                 -1.0
# 749                     1.0            -1.0                 -1.0
# 750                     3.0            -1.0                 -1.0
#
#      value_for_money  recommended aircraft  verified_status  \
# 0                5.0         True      NaN            False
# 1                1.0        False      NaN            False
# 2                5.0         True     A320            False
# 3                1.0        False      NaN            False
# 4                1.0        False   ATR-72             True
# ..               ...          ...      ...              ...
# 746              2.0        False      NaN            False
# 747              4.0         True      NaN            False
# 748              5.0         True      NaN            False
# 749              3.0        False      NaN            False
# 750              2.0        False      NaN            False
#
#                                         review_content
# 0    Such a lovely experience! Service was so good ...
# 1    I recently had a highly disappointing experien...
# 2    I was honestly quite surprised about Air New Z...
# 3    Air New Zealand domestic service is getting wo...
# 4    Air New Zealand bumped us off our flight on th...
# ..                                                 ...
# 746  I have flown with Air New Zealand for several ...
# 747  Flew Wellington-San Francisco (via Auckland). ...
# 748  Flew Premium Economy from LAX to AKL on a 777-...
# 749  Adelaide to Auckland April 28 2013. Usual incr...
# 750  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
# [751 rows x 18 columns]

# %%
# Text cleaning function
def clean_text(text):
    # Preserve exclamations, question marks, and retain original casing
    # Remove unwanted characters but keep punctuation marks important for sentiment
    text = re.sub(r'[^a-zA-Z0-9\s!?.]', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply text cleaning
reviews_df['combined_content'] = reviews_df['header'] + ' ' + reviews_df['review_content'].apply(clean_text)
reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  \
# 0             5.0                  5.0               5.0
# 1             3.0                  4.0               3.0
# 2             5.0                  5.0               5.0
# 3             4.0                  5.0              -1.0
# 4             3.0                  4.0              -1.0
# ..            ...                  ...               ...
# 746           3.0                  2.0               3.0
# 747           5.0                  5.0               5.0
# 748           4.0                  5.0               5.0
# 749           3.0                  3.0               4.0
# 750           3.0                  3.0               4.0
#
#      inflight_entertainment  ground_service  wifi_&_connectivity  \
# 0                       5.0             5.0                  5.0
# 1                       3.0             1.0                  4.0
# 2                      -1.0             5.0                  4.0
# 3                      -1.0             5.0                 -1.0
# 4                      -1.0             1.0                 -1.0
# ..                      ...             ...                  ...
# 746                     4.0            -1.0                 -1.0
# 747                     5.0            -1.0                 -1.0
# 748                     5.0            -1.0                 -1.0
# 749                     1.0            -1.0                 -1.0
# 750                     3.0            -1.0                 -1.0
#
#      value_for_money  recommended aircraft  verified_status  \
# 0                5.0         True      NaN            False
# 1                1.0        False      NaN            False
# 2                5.0         True     A320            False
# 3                1.0        False      NaN            False
# 4                1.0        False   ATR-72             True
# ..               ...          ...      ...              ...
# 746              2.0        False      NaN            False
# 747              4.0         True      NaN            False
# 748              5.0         True      NaN            False
# 749              3.0        False      NaN            False
# 750              2.0        False      NaN            False
#
#                                         review_content  \
# 0    Such a lovely experience! Service was so good ...
# 1    I recently had a highly disappointing experien...
# 2    I was honestly quite surprised about Air New Z...
# 3    Air New Zealand domestic service is getting wo...
# 4    Air New Zealand bumped us off our flight on th...
# ..                                                 ...
# 746  I have flown with Air New Zealand for several ...
# 747  Flew Wellington-San Francisco (via Auckland). ...
# 748  Flew Premium Economy from LAX to AKL on a 777-...
# 749  Adelaide to Auckland April 28 2013. Usual incr...
# 750  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
#                                       combined_content
# 0    Service was so good Such a lovely experience! ...
# 1    a highly disappointing experience I recently h...
# 2    the legroom was huge I was honestly quite surp...
# 3    getting worse by the day Air New Zealand domes...
# 4    never fly Air New Zealand again Air New Zealan...
# ..                                                 ...
# 746  Air New Zealand customer review I have flown w...
# 747  Air New Zealand customer review Flew Wellingto...
# 748  Air New Zealand customer review Flew Premium E...
# 749  Air New Zealand customer review Adelaide to Au...
# 750  Air New Zealand customer review B747400 Premiu...
#
# [751 rows x 19 columns]

# %%
# Define sentiment analysis functions
def get_sentiment_textblob(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    if polarity > 0:
        return 'Positive'
    elif polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# Apply sentiment analysis using TextBlob
reviews_df['textblob_sentiment'] = reviews_df['combined_content'].apply(get_sentiment_textblob)
reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  \
# 0             5.0                  5.0               5.0
# 1             3.0                  4.0               3.0
# 2             5.0                  5.0               5.0
# 3             4.0                  5.0              -1.0
# 4             3.0                  4.0              -1.0
# ..            ...                  ...               ...
# 746           3.0                  2.0               3.0
# 747           5.0                  5.0               5.0
# 748           4.0                  5.0               5.0
# 749           3.0                  3.0               4.0
# 750           3.0                  3.0               4.0
#
#      inflight_entertainment  ground_service  wifi_&_connectivity  \
# 0                       5.0             5.0                  5.0
# 1                       3.0             1.0                  4.0
# 2                      -1.0             5.0                  4.0
# 3                      -1.0             5.0                 -1.0
# 4                      -1.0             1.0                 -1.0
# ..                      ...             ...                  ...
# 746                     4.0            -1.0                 -1.0
# 747                     5.0            -1.0                 -1.0
# 748                     5.0            -1.0                 -1.0
# 749                     1.0            -1.0                 -1.0
# 750                     3.0            -1.0                 -1.0
#
#      value_for_money  recommended aircraft  verified_status  \
# 0                5.0         True      NaN            False
# 1                1.0        False      NaN            False
# 2                5.0         True     A320            False
# 3                1.0        False      NaN            False
# 4                1.0        False   ATR-72             True
# ..               ...          ...      ...              ...
# 746              2.0        False      NaN            False
# 747              4.0         True      NaN            False
# 748              5.0         True      NaN            False
# 749              3.0        False      NaN            False
# 750              2.0        False      NaN            False
#
#                                         review_content  \
# 0    Such a lovely experience! Service was so good ...
# 1    I recently had a highly disappointing experien...
# 2    I was honestly quite surprised about Air New Z...
# 3    Air New Zealand domestic service is getting wo...
# 4    Air New Zealand bumped us off our flight on th...
# ..                                                 ...
# 746  I have flown with Air New Zealand for several ...
# 747  Flew Wellington-San Francisco (via Auckland). ...
# 748  Flew Premium Economy from LAX to AKL on a 777-...
# 749  Adelaide to Auckland April 28 2013. Usual incr...
# 750  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
#                                       combined_content textblob_sentiment
# 0    Service was so good Such a lovely experience! ...           Positive
# 1    a highly disappointing experience I recently h...           Negative
# 2    the legroom was huge I was honestly quite surp...           Positive
# 3    getting worse by the day Air New Zealand domes...           Negative
# 4    never fly Air New Zealand again Air New Zealan...           Negative
# ..                                                 ...                ...
# 746  Air New Zealand customer review I have flown w...           Positive
# 747  Air New Zealand customer review Flew Wellingto...           Positive
# 748  Air New Zealand customer review Flew Premium E...           Positive
# 749  Air New Zealand customer review Adelaide to Au...           Positive
# 750  Air New Zealand customer review B747400 Premiu...           Positive
#
# [751 rows x 20 columns]

# %%
# Calculate sentiment counts
sentiment_counts = reviews_df['textblob_sentiment'].value_counts()
sentiment_counts
# Out:
# textblob_sentiment
# Positive    539
# Negative    210
# Neutral       2
# Name: count, dtype: int64

# %%
# Plot sentiment distribution
plt.figure(figsize=(10, 7))
colors = ['#4CAF50', '#FFC107', '#F44336']  # Colors for Positive, Neutral, Negative
plt.bar(sentiment_counts.index, sentiment_counts.values, color=colors, edgecolor='black', alpha=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Sentiment', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Distribution of Sentiment Categories (TextBlob)', fontsize=16, fontweight='bold')
for i, count in enumerate(sentiment_counts.values):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
def get_sentiment_vader(text):
    analyzer = SentimentIntensityAnalyzer()
    analyzer.lexicon['worst airline'] = -5.0    
    analyzer.lexicon['never fly with Air New Zealand'] = -5.0   

    score = analyzer.polarity_scores(text)['compound']
    if score > 0.1:  
        return 'Positive'
    elif score < -0.1: 
        return 'Negative'
    else:
        return 'Neutral'

# %%
# Apply sentiment analysis using VADER

reviews_df['vader_sentiment'] = reviews_df['combined_content'].apply(get_sentiment_vader)
reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  ...  ground_service  \
# 0             5.0                  5.0               5.0  ...             5.0
# 1             3.0                  4.0               3.0  ...             1.0
# 2             5.0                  5.0               5.0  ...             5.0
# 3             4.0                  5.0              -1.0  ...             5.0
# 4             3.0                  4.0              -1.0  ...             1.0
# ..            ...                  ...               ...  ...             ...
# 746           3.0                  2.0               3.0  ...            -1.0
# 747           5.0                  5.0               5.0  ...            -1.0
# 748           4.0                  5.0               5.0  ...            -1.0
# 749           3.0                  3.0               4.0  ...            -1.0
# 750           3.0                  3.0               4.0  ...            -1.0
#
#      wifi_&_connectivity  value_for_money  recommended  aircraft  \
# 0                    5.0              5.0         True       NaN
# 1                    4.0              1.0        False       NaN
# 2                    4.0              5.0         True      A320
# 3                   -1.0              1.0        False       NaN
# 4                   -1.0              1.0        False    ATR-72
# ..                   ...              ...          ...       ...
# 746                 -1.0              2.0        False       NaN
# 747                 -1.0              4.0         True       NaN
# 748                 -1.0              5.0         True       NaN
# 749                 -1.0              3.0        False       NaN
# 750                 -1.0              2.0        False       NaN
#
#     verified_status                                     review_content  \
# 0             False  Such a lovely experience! Service was so good ...
# 1             False  I recently had a highly disappointing experien...
# 2             False  I was honestly quite surprised about Air New Z...
# 3             False  Air New Zealand domestic service is getting wo...
# 4              True  Air New Zealand bumped us off our flight on th...
# ..              ...                                                ...
# 746           False  I have flown with Air New Zealand for several ...
# 747           False  Flew Wellington-San Francisco (via Auckland). ...
# 748           False  Flew Premium Economy from LAX to AKL on a 777-...
# 749           False  Adelaide to Auckland April 28 2013. Usual incr...
# 750           False  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
#                                       combined_content textblob_sentiment  \
# 0    Service was so good Such a lovely experience! ...           Positive
# 1    a highly disappointing experience I recently h...           Negative
# 2    the legroom was huge I was honestly quite surp...           Positive
# 3    getting worse by the day Air New Zealand domes...           Negative
# 4    never fly Air New Zealand again Air New Zealan...           Negative
# ..                                                 ...                ...
# 746  Air New Zealand customer review I have flown w...           Positive
# 747  Air New Zealand customer review Flew Wellingto...           Positive
# 748  Air New Zealand customer review Flew Premium E...           Positive
# 749  Air New Zealand customer review Adelaide to Au...           Positive
# 750  Air New Zealand customer review B747400 Premiu...           Positive
#
#     vader_sentiment
# 0          Positive
# 1          Negative
# 2          Positive
# 3          Negative
# 4          Negative
# ..              ...
# 746        Positive
# 747        Positive
# 748        Positive
# 749        Positive
# 750        Positive
#
# [751 rows x 21 columns]

# %%
# Calculate sentiment counts
vader_sentiment_counts = reviews_df['vader_sentiment'].value_counts()
vader_sentiment_counts
# Out:
# vader_sentiment
# Positive    446
# Negative    288
# Neutral      17
# Name: count, dtype: int64

# %%
# Plot sentiment distribution
plt.figure(figsize=(10, 7))
colors = ['#4CAF50', '#FFC107', '#F44336']  # Colors for Positive, Neutral, Negative
plt.bar(vader_sentiment_counts.index, vader_sentiment_counts.values, color=colors, edgecolor='black', alpha=0.8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Sentiment', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Distribution of Sentiment Categories (VADER)', fontsize=16, fontweight='bold')
for i, count in enumerate(vader_sentiment_counts.values):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Define function to map ratings to sentiment
def map_rating_to_sentiment(rating):
    if rating >= 8:
        return 'Positive'
    elif rating >= 4:
        return 'Neutral'
    else:
        return 'Negative'
    
# Apply rating to sentiment mapping
reviews_df['rating_sentiment'] = reviews_df['rating'].apply(map_rating_to_sentiment)
reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  ...  \
# 0             5.0                  5.0               5.0  ...
# 1             3.0                  4.0               3.0  ...
# 2             5.0                  5.0               5.0  ...
# 3             4.0                  5.0              -1.0  ...
# 4             3.0                  4.0              -1.0  ...
# ..            ...                  ...               ...  ...
# 746           3.0                  2.0               3.0  ...
# 747           5.0                  5.0               5.0  ...
# 748           4.0                  5.0               5.0  ...
# 749           3.0                  3.0               4.0  ...
# 750           3.0                  3.0               4.0  ...
#
#      wifi_&_connectivity  value_for_money  recommended  aircraft  \
# 0                    5.0              5.0         True       NaN
# 1                    4.0              1.0        False       NaN
# 2                    4.0              5.0         True      A320
# 3                   -1.0              1.0        False       NaN
# 4                   -1.0              1.0        False    ATR-72
# ..                   ...              ...          ...       ...
# 746                 -1.0              2.0        False       NaN
# 747                 -1.0              4.0         True       NaN
# 748                 -1.0              5.0         True       NaN
# 749                 -1.0              3.0        False       NaN
# 750                 -1.0              2.0        False       NaN
#
#      verified_status                                     review_content  \
# 0              False  Such a lovely experience! Service was so good ...
# 1              False  I recently had a highly disappointing experien...
# 2              False  I was honestly quite surprised about Air New Z...
# 3              False  Air New Zealand domestic service is getting wo...
# 4               True  Air New Zealand bumped us off our flight on th...
# ..               ...                                                ...
# 746            False  I have flown with Air New Zealand for several ...
# 747            False  Flew Wellington-San Francisco (via Auckland). ...
# 748            False  Flew Premium Economy from LAX to AKL on a 777-...
# 749            False  Adelaide to Auckland April 28 2013. Usual incr...
# 750            False  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
#                                       combined_content textblob_sentiment  \
# 0    Service was so good Such a lovely experience! ...           Positive
# 1    a highly disappointing experience I recently h...           Negative
# 2    the legroom was huge I was honestly quite surp...           Positive
# 3    getting worse by the day Air New Zealand domes...           Negative
# 4    never fly Air New Zealand again Air New Zealan...           Negative
# ..                                                 ...                ...
# 746  Air New Zealand customer review I have flown w...           Positive
# 747  Air New Zealand customer review Flew Wellingto...           Positive
# 748  Air New Zealand customer review Flew Premium E...           Positive
# 749  Air New Zealand customer review Adelaide to Au...           Positive
# 750  Air New Zealand customer review B747400 Premiu...           Positive
#
#     vader_sentiment rating_sentiment
# 0          Positive         Positive
# 1          Negative          Neutral
# 2          Positive         Positive
# 3          Negative         Negative
# 4          Negative         Negative
# ..              ...              ...
# 746        Positive         Negative
# 747        Positive         Positive
# 748        Positive         Positive
# 749        Positive          Neutral
# 750        Positive          Neutral
#
# [751 rows x 22 columns]

# %%
# Sample reviews for each sentiment type
def sample_reviews(df, sentiment, n=2):
    return df[df['textblob_sentiment'] == sentiment].sample(n=n)

# Sample 2 reviews for each sentiment type
positive_samples = sample_reviews(reviews_df, 'Positive')
neutral_samples = sample_reviews(reviews_df, 'Neutral')
negative_samples = sample_reviews(reviews_df, 'Negative')

# %%
# Combine samples into one DataFrame for easier inspection
sampled_reviews = pd.concat([positive_samples, neutral_samples, negative_samples])

# Display sampled reviews with TextBlob and VADER sentiment labels
print("Sampled Reviews for Sentiment Analysis:")
print(sampled_reviews[['header', 'review_content', 'textblob_sentiment', 'vader_sentiment']])

# Save results to CSV for inspection
reviews_df[['header', 'review_content', 'rating', 'rating_sentiment', 'vader_sentiment', 'textblob_sentiment']].to_csv('../dataset/sentiment_comparison.csv', index=False)
print("Results saved to 'sentiment_comparison.csv'.")
# Out:
# Sampled Reviews for Sentiment Analysis:
#                                        header  \
# 54            Air New Zealand customer review
# 480              inflight safety video is fun
# 59   no response to the reimbursement request
# 163          I want to know why this happened
# 109      What has happened to Air New Zealand
# 137        Double standards. Terrible airline
#
#                                         review_content textblob_sentiment  \
# 54   Best things about Air N.Z. premium economy: 2 ...           Positive
# 480  Second time on Air New Zealand domestic, from ...           Positive
# 59                                        Not Verified            Neutral
# 163  I paid the works for my daughter when I booked...            Neutral
# 109  On 8th November I travelled Sydney to Auckland...           Negative
# 137  Terrible service. I paid for a seat which cost...           Negative
#
#     vader_sentiment
# 54         Positive
# 480        Positive
# 59         Negative
# 163         Neutral
# 109        Positive
# 137        Positive
# Results saved to 'sentiment_comparison.csv'.

# %%
# Calculate confusion matrix and classification report for VADER
y_true = reviews_df['rating_sentiment']
y_pred_vader = reviews_df['vader_sentiment']

conf_matrix_vader = confusion_matrix(y_true, y_pred_vader, labels=['Positive', 'Neutral', 'Negative'])
class_report_vader = classification_report(y_true, y_pred_vader, labels=['Positive', 'Neutral', 'Negative'])

print("Confusion Matrix for VADER:")
print(conf_matrix_vader)
print("\nClassification Report for VADER:")
print(class_report_vader)
# Out:
# Confusion Matrix for VADER:
# [[267   2   3]
#  [102   4  51]
#  [ 77  11 234]]
#
# Classification Report for VADER:
#               precision    recall  f1-score   support
#
#     Positive       0.60      0.98      0.74       272
#      Neutral       0.24      0.03      0.05       157
#     Negative       0.81      0.73      0.77       322
#
#     accuracy                           0.67       751
#    macro avg       0.55      0.58      0.52       751
# weighted avg       0.61      0.67      0.61       751

# %%
# Calculate confusion matrix and classification report for TextBlob
y_pred_textblob = reviews_df['textblob_sentiment']

conf_matrix_textblob = confusion_matrix(y_true, y_pred_textblob, labels=['Positive', 'Neutral', 'Negative'])
class_report_textblob = classification_report(y_true, y_pred_textblob, labels=['Positive', 'Neutral', 'Negative'])

print("Confusion Matrix for TextBlob:")
print(conf_matrix_textblob)
print("\nClassification Report for TextBlob:")
print(class_report_textblob)
# Out:
# Confusion Matrix for TextBlob:
# [[269   0   3]
#  [132   0  25]
#  [138   2 182]]
#
# Classification Report for TextBlob:
#               precision    recall  f1-score   support
#
#     Positive       0.50      0.99      0.66       272
#      Neutral       0.00      0.00      0.00       157
#     Negative       0.87      0.57      0.68       322
#
#     accuracy                           0.60       751
#    macro avg       0.46      0.52      0.45       751
# weighted avg       0.55      0.60      0.53       751

# %%
# Save results to CSV for inspection
reviews_df[['review_content', 'rating', 'rating_sentiment', 'vader_sentiment', 'textblob_sentiment']].to_csv('../dataset/sentiment_comparison.csv', index=False)
print("Results saved to 'sentiment_comparison.csv'.")

# Plot confusion matrices
def plot_confusion_matrix(cm, labels, title):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Sentiment', fontsize=14, fontweight='bold')
    plt.ylabel('True Sentiment', fontsize=14, fontweight='bold')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.show()

plot_confusion_matrix(conf_matrix_vader, labels=['Positive', 'Neutral', 'Negative'], title='Confusion Matrix for VADER')
plot_confusion_matrix(conf_matrix_textblob, labels=['Positive', 'Neutral', 'Negative'], title='Confusion Matrix for TextBlob')
# Out:
# Results saved to 'sentiment_comparison.csv'.

# %%
# Calculate accuracies
def calculate_accuracy(df, sentiment_col):
    return (df['rating_sentiment'] == df[sentiment_col]).mean()

vader_accuracy = calculate_accuracy(reviews_df, 'vader_sentiment')
textblob_accuracy = calculate_accuracy(reviews_df, 'textblob_sentiment')

print(f"VADER Accuracy: {vader_accuracy:.2f}")
print(f"TextBlob Accuracy: {textblob_accuracy:.2f}")
# Out:
# VADER Accuracy: 0.67
# TextBlob Accuracy: 0.60

# %%
accuracy_df = pd.DataFrame({
    'Tool': ['VADER', 'TextBlob'],
    'Accuracy': [vader_accuracy, textblob_accuracy]
})


plt.figure(figsize=(8, 5))
sns.barplot(x='Tool', y='Accuracy', data=accuracy_df, palette='viridis')
plt.ylim(0, 1)  
plt.xlabel('Sentiment Analysis Tool', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
plt.title('Accuracy of Sentiment Analysis Tools', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)


for index, value in enumerate(accuracy_df['Accuracy']):
    plt.text(index, value + 0.02, f'{value:.2f}', ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/1864585545.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Tool', y='Accuracy', data=accuracy_df, palette='viridis')

# %%
# Convert 'date' to datetime and extract the year
reviews_df['year'] = pd.to_datetime(reviews_df['date'], format='%Y-%m-%d').dt.year

# Number of reviews aggregated by year and sentiment
sentiment_by_year = reviews_df.groupby(['year', 'vader_sentiment']).size().unstack(fill_value=0)

sentiment_by_year
# Out:
# vader_sentiment  Negative  Neutral  Positive
# year
# 2013                   18        2        56
# 2014                   18        1        67
# 2015                   14        1        54
# 2016                   17        0        57
# 2017                   19        2        49
# 2018                   32        2        44
# 2019                   51        1        29
# 2020                   26        3        16
# 2021                   15        1         9
# 2022                   24        2        26
# 2023                   38        2        29
# 2024                   16        0        10

# %%
reviews_df.to_csv("../dataset/reviews_with_sentiments.csv", index=False)

# %% [markdown]
# # How do domestic & international routes compare in terms of review ratings?

# %%
import pandas as pd

cleaned_reviews = "../dataset/reviews_with_sentiments.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df.head()
# Out:
#          date                             header  rating type_of_traveller  \
# 0  2024-09-15                Service was so good      10          Business
# 1  2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2  2024-08-29               the legroom was huge       9    Family Leisure
# 3  2024-08-19           getting worse by the day       3          Business
# 4  2024-08-13    never fly Air New Zealand again       1    Family Leisure
#
#        seat_type                             route     date_flown  \
# 0  Economy Class                Melbourne to Tokyo    August 2024
# 1  Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2  Economy Class            Auckland to Queenstown  December 2023
# 3  Economy Class                Auckland to Napier    August 2024
# 4  Economy Class                Napier to Auckland      June 2024
#
#    seat_comfort  cabin_staff_service  food_&_beverages  ...  value_for_money  \
# 0           5.0                  5.0               5.0  ...              5.0
# 1           3.0                  4.0               3.0  ...              1.0
# 2           5.0                  5.0               5.0  ...              5.0
# 3           4.0                  5.0              -1.0  ...              1.0
# 4           3.0                  4.0              -1.0  ...              1.0
#
#    recommended  aircraft  verified_status  \
# 0         True       NaN            False
# 1        False       NaN            False
# 2         True      A320            False
# 3        False       NaN            False
# 4        False    ATR-72             True
#
#                                       review_content  \
# 0  Such a lovely experience! Service was so good ...
# 1  I recently had a highly disappointing experien...
# 2  I was honestly quite surprised about Air New Z...
# 3  Air New Zealand domestic service is getting wo...
# 4  Air New Zealand bumped us off our flight on th...
#
#                                     combined_content  textblob_sentiment  \
# 0  Service was so good Such a lovely experience! ...            Positive
# 1  a highly disappointing experience I recently h...            Negative
# 2  the legroom was huge I was honestly quite surp...            Positive
# 3  getting worse by the day Air New Zealand domes...            Negative
# 4  never fly Air New Zealand again Air New Zealan...            Negative
#
#   vader_sentiment rating_sentiment  year
# 0        Positive         Positive  2024
# 1        Negative          Neutral  2024
# 2        Positive         Positive  2024
# 3        Negative         Negative  2024
# 4        Negative         Negative  2024
#
# [5 rows x 23 columns]

# %%
# Function to split the route into departure, arrival, and via
def split_route(route):
    # Check if the route is not NaN (missing value)
    if pd.isna(route):
        return pd.Series([None, None, None])
    
    # Split by "to" first
    if 'to' in route:
        departure, arrival_part = route.split(' to ', 1)
        
        # Check if "via" is present in the arrival part
        if 'via' in arrival_part:
            arrival, via = arrival_part.split(' via ', 1)
            return pd.Series([departure.strip(), arrival.strip(), via.strip()])
        else:
            return pd.Series([departure.strip(), arrival_part.strip(), None])
    else:
        return pd.Series([None, None, None])

reviews_df[['departure', 'arrival', 'via']] = reviews_df['route'].apply(split_route)

reviews_df[['route', 'departure', 'arrival', 'via']].head()
# Out:
#                               route  departure     arrival     via
# 0                Melbourne to Tokyo  Melbourne       Tokyo    None
# 1  Raratonga to Auckland via Taipei  Raratonga    Auckland  Taipei
# 2            Auckland to Queenstown   Auckland  Queenstown    None
# 3                Auckland to Napier   Auckland      Napier    None
# 4                Napier to Auckland     Napier    Auckland    None

# %%
# Load the New Zealand airports dataset
nz_airports = "../dataset/nz_airports.csv"
nz_airports_df = pd.read_csv(nz_airports)

nz_airports_df['Municipality'] = nz_airports_df['Municipality'].str.lower()
reviews_df['departure'] = reviews_df['departure'].str.lower()
reviews_df['arrival'] = reviews_df['arrival'].str.lower()

nz_airports_df[['Municipality', 'ISO_Country']].head()
# Out:
#    Municipality ISO_Country
# 0      auckland          NZ
# 1         taupo          NZ
# 2  christchurch          NZ
# 3        te one          NZ
# 4       dunedin          NZ

# %%
# Merge only departure first to test merging process
reviews_with_departure_country = reviews_df.merge(nz_airports_df[['Municipality', 'ISO_Country']], 
                                                  left_on='departure', 
                                                  right_on='Municipality', 
                                                  how='left')

# Rename the iso_country column to departure_country
reviews_with_departure_country = reviews_with_departure_country.rename(columns={'ISO_Country': 'departure_country'})

# Sample to verify
reviews_with_departure_country
# Out:
#             date                             header  rating type_of_traveller  \
# 0     2024-09-15                Service was so good      10          Business
# 1     2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2     2024-08-29               the legroom was huge       9    Family Leisure
# 3     2024-08-19           getting worse by the day       3          Business
# 4     2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ...          ...                                ...     ...               ...
# 1313  2013-05-06    Air New Zealand customer review       5               NaN
# 1314  2013-05-01    Air New Zealand customer review       5               NaN
# 1315  2013-05-01    Air New Zealand customer review       5               NaN
# 1316  2013-05-01    Air New Zealand customer review       5               NaN
# 1317  2013-05-01    Air New Zealand customer review       5               NaN
#
#             seat_type                             route     date_flown  \
# 0       Economy Class                Melbourne to Tokyo    August 2024
# 1       Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2       Economy Class            Auckland to Queenstown  December 2023
# 3       Economy Class                Auckland to Napier    August 2024
# 4       Economy Class                Napier to Auckland      June 2024
# ...               ...                               ...            ...
# 1313    Economy Class                               NaN            NaN
# 1314  Premium Economy                               NaN            NaN
# 1315  Premium Economy                               NaN            NaN
# 1316  Premium Economy                               NaN            NaN
# 1317  Premium Economy                               NaN            NaN
#
#       seat_comfort  cabin_staff_service  food_&_beverages  ...  \
# 0              5.0                  5.0               5.0  ...
# 1              3.0                  4.0               3.0  ...
# 2              5.0                  5.0               5.0  ...
# 3              4.0                  5.0              -1.0  ...
# 4              3.0                  4.0              -1.0  ...
# ...            ...                  ...               ...  ...
# 1313           3.0                  3.0               4.0  ...
# 1314           3.0                  3.0               4.0  ...
# 1315           3.0                  3.0               4.0  ...
# 1316           3.0                  3.0               4.0  ...
# 1317           3.0                  3.0               4.0  ...
#
#                                        combined_content  textblob_sentiment  \
# 0     Service was so good Such a lovely experience! ...            Positive
# 1     a highly disappointing experience I recently h...            Negative
# 2     the legroom was huge I was honestly quite surp...            Positive
# 3     getting worse by the day Air New Zealand domes...            Negative
# 4     never fly Air New Zealand again Air New Zealan...            Negative
# ...                                                 ...                 ...
# 1313  Air New Zealand customer review Adelaide to Au...            Positive
# 1314  Air New Zealand customer review B747400 Premiu...            Positive
# 1315  Air New Zealand customer review B747400 Premiu...            Positive
# 1316  Air New Zealand customer review B747400 Premiu...            Positive
# 1317  Air New Zealand customer review B747400 Premiu...            Positive
#
#       vader_sentiment  rating_sentiment  year  departure     arrival     via  \
# 0            Positive          Positive  2024  melbourne       tokyo    None
# 1            Negative           Neutral  2024  raratonga    auckland  Taipei
# 2            Positive          Positive  2024   auckland  queenstown    None
# 3            Negative          Negative  2024   auckland      napier    None
# 4            Negative          Negative  2024     napier    auckland    None
# ...               ...               ...   ...        ...         ...     ...
# 1313         Positive           Neutral  2013       None        None    None
# 1314         Positive           Neutral  2013       None        None    None
# 1315         Positive           Neutral  2013       None        None    None
# 1316         Positive           Neutral  2013       None        None    None
# 1317         Positive           Neutral  2013       None        None    None
#
#      Municipality departure_country
# 0             NaN               NaN
# 1             NaN               NaN
# 2        auckland                NZ
# 3        auckland                NZ
# 4          napier                NZ
# ...           ...               ...
# 1313          NaN                NZ
# 1314          NaN                NZ
# 1315          NaN                NZ
# 1316          NaN                NZ
# 1317          NaN                NZ
#
# [1318 rows x 28 columns]

# %%
# Now merge arrival country
reviews_with_full_country = reviews_with_departure_country.merge(nz_airports_df[['Municipality', 'ISO_Country']], 
                                                                 left_on='arrival', 
                                                                 right_on='Municipality', 
                                                                 how='left')

# Rename the iso_country column to arrival_country
reviews_with_full_country = reviews_with_full_country.rename(columns={'ISO_Country': 'arrival_country'})

# Verify the merge
print(reviews_with_full_country[['arrival', 'arrival_country']].head())
# Out:
#       arrival arrival_country
# 0       tokyo             NaN
# 1    auckland              NZ
# 2  queenstown              NZ
# 3      napier              NZ
# 4    auckland              NZ

# %%
reviews_with_full_country['departure_country'] = reviews_with_full_country.apply(
    lambda row: row['departure_country'] if pd.notna(row['departure']) else None, axis=1
)
reviews_with_full_country['arrival_country'] = reviews_with_full_country.apply(
    lambda row: row['arrival_country'] if pd.notna(row['arrival']) else None, axis=1
)

reviews_with_full_country
# Out:
#             date                             header  rating type_of_traveller  \
# 0     2024-09-15                Service was so good      10          Business
# 1     2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2     2024-08-29               the legroom was huge       9    Family Leisure
# 3     2024-08-19           getting worse by the day       3          Business
# 4     2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ...          ...                                ...     ...               ...
# 3581  2013-05-01    Air New Zealand customer review       5               NaN
# 3582  2013-05-01    Air New Zealand customer review       5               NaN
# 3583  2013-05-01    Air New Zealand customer review       5               NaN
# 3584  2013-05-01    Air New Zealand customer review       5               NaN
# 3585  2013-05-01    Air New Zealand customer review       5               NaN
#
#             seat_type                             route     date_flown  \
# 0       Economy Class                Melbourne to Tokyo    August 2024
# 1       Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2       Economy Class            Auckland to Queenstown  December 2023
# 3       Economy Class                Auckland to Napier    August 2024
# 4       Economy Class                Napier to Auckland      June 2024
# ...               ...                               ...            ...
# 3581  Premium Economy                               NaN            NaN
# 3582  Premium Economy                               NaN            NaN
# 3583  Premium Economy                               NaN            NaN
# 3584  Premium Economy                               NaN            NaN
# 3585  Premium Economy                               NaN            NaN
#
#       seat_comfort  cabin_staff_service  food_&_beverages  ...  \
# 0              5.0                  5.0               5.0  ...
# 1              3.0                  4.0               3.0  ...
# 2              5.0                  5.0               5.0  ...
# 3              4.0                  5.0              -1.0  ...
# 4              3.0                  4.0              -1.0  ...
# ...            ...                  ...               ...  ...
# 3581           3.0                  3.0               4.0  ...
# 3582           3.0                  3.0               4.0  ...
# 3583           3.0                  3.0               4.0  ...
# 3584           3.0                  3.0               4.0  ...
# 3585           3.0                  3.0               4.0  ...
#
#       vader_sentiment  rating_sentiment  year  departure     arrival     via  \
# 0            Positive          Positive  2024  melbourne       tokyo    None
# 1            Negative           Neutral  2024  raratonga    auckland  Taipei
# 2            Positive          Positive  2024   auckland  queenstown    None
# 3            Negative          Negative  2024   auckland      napier    None
# 4            Negative          Negative  2024     napier    auckland    None
# ...               ...               ...   ...        ...         ...     ...
# 3581         Positive           Neutral  2013       None        None    None
# 3582         Positive           Neutral  2013       None        None    None
# 3583         Positive           Neutral  2013       None        None    None
# 3584         Positive           Neutral  2013       None        None    None
# 3585         Positive           Neutral  2013       None        None    None
#
#       Municipality_x departure_country Municipality_y arrival_country
# 0                NaN               NaN            NaN             NaN
# 1                NaN               NaN       auckland              NZ
# 2           auckland                NZ     queenstown              NZ
# 3           auckland                NZ         napier              NZ
# 4             napier                NZ       auckland              NZ
# ...              ...               ...            ...             ...
# 3581             NaN              None            NaN            None
# 3582             NaN              None            NaN            None
# 3583             NaN              None            NaN            None
# 3584             NaN              None            NaN            None
# 3585             NaN              None            NaN            None
#
# [3586 rows x 30 columns]

# %%
duplicate_reviews = reviews_df[reviews_df.duplicated(subset=['review_content'], keep=False)]
print(duplicate_reviews)
# Out:
# Empty DataFrame
# Columns: [date, header, rating, type_of_traveller, seat_type, route, date_flown, seat_comfort, cabin_staff_service, food_&_beverages, inflight_entertainment, ground_service, wifi_&_connectivity, value_for_money, recommended, aircraft, verified_status, review_content, combined_content, textblob_sentiment, vader_sentiment, rating_sentiment, year, departure, arrival, via]
# Index: []
#
# [0 rows x 26 columns]

# %%
reviews_df = reviews_df.drop_duplicates(subset=['review_content']) 

reviews_df
# Out:
#            date                             header  rating type_of_traveller  \
# 0    2024-09-15                Service was so good      10          Business
# 1    2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2    2024-08-29               the legroom was huge       9    Family Leisure
# 3    2024-08-19           getting worse by the day       3          Business
# 4    2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ..          ...                                ...     ...               ...
# 746  2013-05-12    Air New Zealand customer review       3               NaN
# 747  2013-05-10    Air New Zealand customer review      10               NaN
# 748  2013-05-08    Air New Zealand customer review       9               NaN
# 749  2013-05-06    Air New Zealand customer review       5               NaN
# 750  2013-05-01    Air New Zealand customer review       5               NaN
#
#            seat_type                             route     date_flown  \
# 0      Economy Class                Melbourne to Tokyo    August 2024
# 1      Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2      Economy Class            Auckland to Queenstown  December 2023
# 3      Economy Class                Auckland to Napier    August 2024
# 4      Economy Class                Napier to Auckland      June 2024
# ..               ...                               ...            ...
# 746    Economy Class                               NaN            NaN
# 747  Premium Economy                               NaN            NaN
# 748  Premium Economy                               NaN            NaN
# 749    Economy Class                               NaN            NaN
# 750  Premium Economy                               NaN            NaN
#
#      seat_comfort  cabin_staff_service  food_&_beverages  ...  \
# 0             5.0                  5.0               5.0  ...
# 1             3.0                  4.0               3.0  ...
# 2             5.0                  5.0               5.0  ...
# 3             4.0                  5.0              -1.0  ...
# 4             3.0                  4.0              -1.0  ...
# ..            ...                  ...               ...  ...
# 746           3.0                  2.0               3.0  ...
# 747           5.0                  5.0               5.0  ...
# 748           4.0                  5.0               5.0  ...
# 749           3.0                  3.0               4.0  ...
# 750           3.0                  3.0               4.0  ...
#
#      verified_status                                     review_content  \
# 0              False  Such a lovely experience! Service was so good ...
# 1              False  I recently had a highly disappointing experien...
# 2              False  I was honestly quite surprised about Air New Z...
# 3              False  Air New Zealand domestic service is getting wo...
# 4               True  Air New Zealand bumped us off our flight on th...
# ..               ...                                                ...
# 746            False  I have flown with Air New Zealand for several ...
# 747            False  Flew Wellington-San Francisco (via Auckland). ...
# 748            False  Flew Premium Economy from LAX to AKL on a 777-...
# 749            False  Adelaide to Auckland April 28 2013. Usual incr...
# 750            False  B747-400 Premium Economy SFO-AKL B767 Works AK...
#
#                                       combined_content  textblob_sentiment  \
# 0    Service was so good Such a lovely experience! ...            Positive
# 1    a highly disappointing experience I recently h...            Negative
# 2    the legroom was huge I was honestly quite surp...            Positive
# 3    getting worse by the day Air New Zealand domes...            Negative
# 4    never fly Air New Zealand again Air New Zealan...            Negative
# ..                                                 ...                 ...
# 746  Air New Zealand customer review I have flown w...            Positive
# 747  Air New Zealand customer review Flew Wellingto...            Positive
# 748  Air New Zealand customer review Flew Premium E...            Positive
# 749  Air New Zealand customer review Adelaide to Au...            Positive
# 750  Air New Zealand customer review B747400 Premiu...            Positive
#
#      vader_sentiment rating_sentiment  year  departure     arrival     via
# 0           Positive         Positive  2024  melbourne       tokyo    None
# 1           Negative          Neutral  2024  raratonga    auckland  Taipei
# 2           Positive         Positive  2024   auckland  queenstown    None
# 3           Negative         Negative  2024   auckland      napier    None
# 4           Negative         Negative  2024     napier    auckland    None
# ..               ...              ...   ...        ...         ...     ...
# 746         Positive         Negative  2013       None        None    None
# 747         Positive         Positive  2013       None        None    None
# 748         Positive         Positive  2013       None        None    None
# 749         Positive          Neutral  2013       None        None    None
# 750         Positive          Neutral  2013       None        None    None
#
# [751 rows x 26 columns]

# %%
# Load general airports dataset
airports_df = pd.read_csv("../dataset/airports.csv")

airports_df['municipality'] = airports_df['municipality'].str.lower()
airports_df['iata_code'] = airports_df['iata_code'].str.lower()

# Handle NaN departure_country
nan_departure_country = reviews_with_full_country[reviews_with_full_country['departure_country'].isna()]
nan_departure_municipalities = nan_departure_country['departure'].unique()

# Find corresponding ISO country from airports_df
nan_departure_countries = airports_df[airports_df['municipality'].isin(nan_departure_municipalities)]
municipality_to_country = dict(zip(nan_departure_countries['municipality'], nan_departure_countries['iso_country']))

# Update departure_country
reviews_with_full_country['departure_country'] = reviews_with_full_country['departure'].map(municipality_to_country).fillna(reviews_with_full_country['departure_country'])

# Handle NaN arrival_country similarly
nan_arrival_country = reviews_with_full_country[reviews_with_full_country['arrival_country'].isna()]
nan_arrival_municipalities = nan_arrival_country['arrival'].unique()

# Find corresponding ISO country for arrival
nan_arrival_countries = airports_df[airports_df['municipality'].isin(nan_arrival_municipalities)]
municipality_to_country = dict(zip(nan_arrival_countries['municipality'], nan_arrival_countries['iso_country']))

# Update arrival_country
reviews_with_full_country['arrival_country'] = reviews_with_full_country['arrival'].map(municipality_to_country).fillna(reviews_with_full_country['arrival_country'])
reviews_with_full_country
# Out:
#             date                             header  rating type_of_traveller  \
# 0     2024-09-15                Service was so good      10          Business
# 1     2024-09-12  a highly disappointing experience       4      Solo Leisure
# 2     2024-08-29               the legroom was huge       9    Family Leisure
# 3     2024-08-19           getting worse by the day       3          Business
# 4     2024-08-13    never fly Air New Zealand again       1    Family Leisure
# ...          ...                                ...     ...               ...
# 3581  2013-05-01    Air New Zealand customer review       5               NaN
# 3582  2013-05-01    Air New Zealand customer review       5               NaN
# 3583  2013-05-01    Air New Zealand customer review       5               NaN
# 3584  2013-05-01    Air New Zealand customer review       5               NaN
# 3585  2013-05-01    Air New Zealand customer review       5               NaN
#
#             seat_type                             route     date_flown  \
# 0       Economy Class                Melbourne to Tokyo    August 2024
# 1       Economy Class  Raratonga to Auckland via Taipei    August 2024
# 2       Economy Class            Auckland to Queenstown  December 2023
# 3       Economy Class                Auckland to Napier    August 2024
# 4       Economy Class                Napier to Auckland      June 2024
# ...               ...                               ...            ...
# 3581  Premium Economy                               NaN            NaN
# 3582  Premium Economy                               NaN            NaN
# 3583  Premium Economy                               NaN            NaN
# 3584  Premium Economy                               NaN            NaN
# 3585  Premium Economy                               NaN            NaN
#
#       seat_comfort  cabin_staff_service  food_&_beverages  ...  \
# 0              5.0                  5.0               5.0  ...
# 1              3.0                  4.0               3.0  ...
# 2              5.0                  5.0               5.0  ...
# 3              4.0                  5.0              -1.0  ...
# 4              3.0                  4.0              -1.0  ...
# ...            ...                  ...               ...  ...
# 3581           3.0                  3.0               4.0  ...
# 3582           3.0                  3.0               4.0  ...
# 3583           3.0                  3.0               4.0  ...
# 3584           3.0                  3.0               4.0  ...
# 3585           3.0                  3.0               4.0  ...
#
#       vader_sentiment  rating_sentiment  year  departure     arrival     via  \
# 0            Positive          Positive  2024  melbourne       tokyo    None
# 1            Negative           Neutral  2024  raratonga    auckland  Taipei
# 2            Positive          Positive  2024   auckland  queenstown    None
# 3            Negative          Negative  2024   auckland      napier    None
# 4            Negative          Negative  2024     napier    auckland    None
# ...               ...               ...   ...        ...         ...     ...
# 3581         Positive           Neutral  2013       None        None    None
# 3582         Positive           Neutral  2013       None        None    None
# 3583         Positive           Neutral  2013       None        None    None
# 3584         Positive           Neutral  2013       None        None    None
# 3585         Positive           Neutral  2013       None        None    None
#
#       Municipality_x departure_country Municipality_y arrival_country
# 0                NaN                AU            NaN              JP
# 1                NaN               NaN       auckland              NZ
# 2           auckland                NZ     queenstown              NZ
# 3           auckland                NZ         napier              NZ
# 4             napier                NZ       auckland              NZ
# ...              ...               ...            ...             ...
# 3581             NaN              None            NaN            None
# 3582             NaN              None            NaN            None
# 3583             NaN              None            NaN            None
# 3584             NaN              None            NaN            None
# 3585             NaN              None            NaN            None
#
# [3586 rows x 30 columns]

# %%
airports = "../dataset/airports.csv"
airports_df = pd.read_csv(airports)

airports_df['municipality'] = airports_df['municipality'].str.lower()
airports_df['iata_code'] = airports_df['iata_code'].str.lower()

# %%
# Map IATA code to ISO country
iata_to_country = dict(zip(airports_df['iata_code'], airports_df['iso_country']))

# %%
# Function to get ISO country from IATA code
def get_country_from_iata(iata_code, mapping):
    return mapping.get(iata_code, None)

# Update 'departure_country' using the IATA code
reviews_with_full_country['departure_country'] = reviews_with_full_country.apply(
    lambda row: get_country_from_iata(row['departure'], iata_to_country) if pd.isna(row['departure_country']) and pd.notna(row['departure']) else row['departure_country'], axis=1
)

# Update 'arrival_country' using the IATA code
reviews_with_full_country['arrival_country'] = reviews_with_full_country.apply(
    lambda row: get_country_from_iata(row['arrival'], iata_to_country) if pd.isna(row['arrival_country']) and pd.notna(row['arrival']) else row['arrival_country'], axis=1
)

# %%
print(reviews_with_full_country[['departure', 'departure_country', 'arrival', 'arrival_country']].head())
# Out:
#    departure departure_country     arrival arrival_country
# 0  melbourne                AU       tokyo              JP
# 1  raratonga              None    auckland              NZ
# 2   auckland                NZ  queenstown              NZ
# 3   auckland                NZ      napier              NZ
# 4     napier                NZ    auckland              NZ

# %%
# Define the columns you want to keep
columns_to_keep = ['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
                    'seat_type', 'route', 'date_flown', 'seat_comfort',
                    'cabin_staff_service', 'food_&_beverages', 'ground_service',
                    'wifi_&_connectivity', 'value_for_money', 'recommended',
                    'inflight_entertainment', 'verified_status', 'review_content', 
                    'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
                    'departure', 'departure_country', 'arrival', 'arrival_country', 'via']

# Select only the necessary columns
nz_reviews_with_routes_df = reviews_with_full_country[columns_to_keep]

nz_reviews_with_routes_df.head()
# Out:
#          date                             header  rating aircraft  \
# 0  2024-09-15                Service was so good      10      NaN
# 1  2024-09-12  a highly disappointing experience       4      NaN
# 2  2024-08-29               the legroom was huge       9     A320
# 3  2024-08-19           getting worse by the day       3      NaN
# 4  2024-08-13    never fly Air New Zealand again       1   ATR-72
#
#   type_of_traveller      seat_type                             route  \
# 0          Business  Economy Class                Melbourne to Tokyo
# 1      Solo Leisure  Economy Class  Raratonga to Auckland via Taipei
# 2    Family Leisure  Economy Class            Auckland to Queenstown
# 3          Business  Economy Class                Auckland to Napier
# 4    Family Leisure  Economy Class                Napier to Auckland
#
#       date_flown  seat_comfort  cabin_staff_service  ...  \
# 0    August 2024           5.0                  5.0  ...
# 1    August 2024           3.0                  4.0  ...
# 2  December 2023           5.0                  5.0  ...
# 3    August 2024           4.0                  5.0  ...
# 4      June 2024           3.0                  4.0  ...
#
#                                       review_content  textblob_sentiment  \
# 0  Such a lovely experience! Service was so good ...            Positive
# 1  I recently had a highly disappointing experien...            Negative
# 2  I was honestly quite surprised about Air New Z...            Positive
# 3  Air New Zealand domestic service is getting wo...            Negative
# 4  Air New Zealand bumped us off our flight on th...            Negative
#
#    vader_sentiment  rating_sentiment  year  departure  departure_country  \
# 0         Positive          Positive  2024  melbourne                 AU
# 1         Negative           Neutral  2024  raratonga               None
# 2         Positive          Positive  2024   auckland                 NZ
# 3         Negative          Negative  2024   auckland                 NZ
# 4         Negative          Negative  2024     napier                 NZ
#
#       arrival arrival_country     via
# 0       tokyo              JP    None
# 1    auckland              NZ  Taipei
# 2  queenstown              NZ    None
# 3      napier              NZ    None
# 4    auckland              NZ    None
#
# [5 rows x 27 columns]

# %%
# Drop duplicates in the DataFrame
nz_reviews_with_routes_df = nz_reviews_with_routes_df.drop_duplicates()

# Drop rows where either 'departure' or 'arrival' is NaN
nz_reviews_with_routes_df = nz_reviews_with_routes_df.dropna(subset=['departure', 'arrival'])

nz_reviews_with_routes_df.head()
# Out:
#          date                             header  rating aircraft  \
# 0  2024-09-15                Service was so good      10      NaN
# 1  2024-09-12  a highly disappointing experience       4      NaN
# 2  2024-08-29               the legroom was huge       9     A320
# 3  2024-08-19           getting worse by the day       3      NaN
# 4  2024-08-13    never fly Air New Zealand again       1   ATR-72
#
#   type_of_traveller      seat_type                             route  \
# 0          Business  Economy Class                Melbourne to Tokyo
# 1      Solo Leisure  Economy Class  Raratonga to Auckland via Taipei
# 2    Family Leisure  Economy Class            Auckland to Queenstown
# 3          Business  Economy Class                Auckland to Napier
# 4    Family Leisure  Economy Class                Napier to Auckland
#
#       date_flown  seat_comfort  cabin_staff_service  ...  \
# 0    August 2024           5.0                  5.0  ...
# 1    August 2024           3.0                  4.0  ...
# 2  December 2023           5.0                  5.0  ...
# 3    August 2024           4.0                  5.0  ...
# 4      June 2024           3.0                  4.0  ...
#
#                                       review_content  textblob_sentiment  \
# 0  Such a lovely experience! Service was so good ...            Positive
# 1  I recently had a highly disappointing experien...            Negative
# 2  I was honestly quite surprised about Air New Z...            Positive
# 3  Air New Zealand domestic service is getting wo...            Negative
# 4  Air New Zealand bumped us off our flight on th...            Negative
#
#    vader_sentiment  rating_sentiment  year  departure  departure_country  \
# 0         Positive          Positive  2024  melbourne                 AU
# 1         Negative           Neutral  2024  raratonga               None
# 2         Positive          Positive  2024   auckland                 NZ
# 3         Negative          Negative  2024   auckland                 NZ
# 4         Negative          Negative  2024     napier                 NZ
#
#       arrival arrival_country     via
# 0       tokyo              JP    None
# 1    auckland              NZ  Taipei
# 2  queenstown              NZ    None
# 3      napier              NZ    None
# 4    auckland              NZ    None
#
# [5 rows x 27 columns]

# %%
# Filter rows where 'departure' or 'arrival' contains 'bne'
bne_reviews = nz_reviews_with_routes_df[(nz_reviews_with_routes_df['departure'] == 'bne') | (nz_reviews_with_routes_df['arrival'] == 'bne')]

bne_reviews
# Out:
#            date                              header  rating  \
# 472  2017-01-10     food very good and wine sublime      10
# 475  2017-01-01        Air New Zealand cost cutting       8
# 489  2016-11-22      never fly with Air New Zealand       1
# 492  2016-10-22      everything proved very average       6
# 503  2016-08-30  never travel Air New Zealand again       1
# 520  2016-06-25           crews were very attentive       9
# 535  2016-03-21              a very pleasant flight       8
# 540  2016-03-01      there are better options to US       5
# 592  2015-06-26     Air New Zealand customer review       9
#
#                  aircraft type_of_traveller       seat_type  \
# 472  Boeing777-300 / A320    Couple Leisure  Business Class
# 475                  A320      Solo Leisure   Economy Class
# 489                   NaN    Couple Leisure   Economy Class
# 492                  A320    Couple Leisure   Economy Class
# 503                   NaN    Family Leisure   Economy Class
# 520        Boeing 777-300          Business  Business Class
# 535            Boeing 777    Couple Leisure   Economy Class
# 540      Boeing 777-300ER    Couple Leisure   Economy Class
# 592               777-300          Business  Business Class
#
#                   route     date_flown  seat_comfort  cabin_staff_service  \
# 472  BNE to WLG via AKL   January 2017           5.0                  5.0
# 475          CHC to BNE   January 2017           4.0                  4.0
# 489          BNE to NLK  November 2016          -1.0                 -1.0
# 492          CHC to BNE   October 2016           3.0                  4.0
# 503          ZQN to BNE    August 2016           1.0                  1.0
# 520  BNE to SFO via AKL      June 2016           5.0                  5.0
# 535          BNE to AKL     March 2016           4.0                  5.0
# 540  BNE to LAX via AKL  February 2016           2.0                  4.0
# 592  LAX to BNE via AKL      June 2015           5.0                  5.0
#
#      ...                                     review_content  \
# 472  ...  Brisbane to Wellington via Auckland. The servi...
# 475  ...  NZ805 Christchurch to Brisbane. I consider thi...
# 489  ...  My parents were flying Brisbane to Norfolk Isl...
# 492  ...  Flew Christchurch to Brisbane. Air New Zealand...
# 503  ...  I was absolutely shocked and disgusted to disc...
# 520  ...  Brisbane to San Francisco via Auckland with Ai...
# 535  ...  Brisbane to Auckland with Air New Zealand was ...
# 540  ...  Brisbane to Los Angeles via Auckland and the f...
# 592  ...  Two wonderful flights with engaging and helpfu...
#
#      textblob_sentiment  vader_sentiment  rating_sentiment  year  departure  \
# 472            Positive         Positive          Positive  2017        bne
# 475            Positive         Positive          Positive  2017        chc
# 489            Negative         Positive          Negative  2016        bne
# 492            Positive         Positive           Neutral  2016        chc
# 503            Negative         Negative          Negative  2016        zqn
# 520            Positive         Negative          Positive  2016        bne
# 535            Positive         Positive          Positive  2016        bne
# 540            Positive         Positive           Neutral  2016        bne
# 592            Positive         Positive          Positive  2015        lax
#
#      departure_country arrival arrival_country   via
# 472                 AU     wlg              NZ   AKL
# 475                 NZ     bne              AU  None
# 489                 AU     nlk              NF  None
# 492                 NZ     bne              AU  None
# 503                 NZ     bne              AU  None
# 520                 AU     sfo              US   AKL
# 535                 AU     akl              NZ  None
# 540                 AU     lax              US   AKL
# 592                 US     bne              AU   AKL
#
# [9 rows x 27 columns]

# %%
# Determine if a route is domestic or international
nz_reviews_with_routes_df['is_domestic'] = (nz_reviews_with_routes_df['departure_country'] == 'NZ') & (nz_reviews_with_routes_df['arrival_country'] == 'NZ')

# Count domestic and international routes
route_counts = nz_reviews_with_routes_df['is_domestic'].value_counts()

# Prepare labels and values for plotting
labels = ['Domestic', 'International']
values = route_counts.values

# Print counts for verification
print(f"Domestic routes: {route_counts[True]}")
print(f"International routes: {route_counts[False]}")
# Out:
# Domestic routes: 114
# International routes: 448

# %%
# Pie chart for domestic and international routes
plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['blue', 'orange'])
plt.title('Percentage of Domestic vs International Routes')
plt.show()

# %%
nz_reviews_with_routes_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content',
#        'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
#        'departure', 'departure_country', 'arrival', 'arrival_country', 'via',
#        'is_domestic'],
#       dtype='object')

# %%
# Inspect the dataset for missing values
nz_reviews_with_routes_df[rating_columns].isnull().sum()

# Check the distribution of domestic and international routes
nz_reviews_with_routes_df['is_domestic'].value_counts()
# Out:
# is_domestic
# False    448
# True     114
# Name: count, dtype: int64

# %%
# List of rating columns
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service',
                   'wifi_&_connectivity', 'value_for_money', 'inflight_entertainment']

# Calculate average ratings for each category by route type
average_ratings = nz_reviews_with_routes_df.groupby(['is_domestic'])[rating_columns].mean().reset_index()

# Display the average ratings
average_ratings
# Out:
#    is_domestic  seat_comfort  cabin_staff_service  food_&_beverages  \
# 0        False      2.783482             2.997768          2.352679
# 1         True      2.605263             2.903509          1.210526
#
#    ground_service  wifi_&_connectivity  value_for_money  \
# 0        2.774554             0.191964         2.747768
# 1        2.263158            -0.298246         2.377193
#
#    inflight_entertainment
# 0                2.616071
# 1               -0.105263

# %%
# Melt the DataFrame to long format
average_ratings_melted = average_ratings.melt(id_vars=['is_domestic'], 
                                              value_vars=rating_columns,
                                              var_name='category', 
                                              value_name='average_rating')

plt.figure(figsize=(14, 8))

sns.barplot(data=average_ratings_melted, x='category', y='average_rating', hue='is_domestic', palette='coolwarm')

plt.title('Average Ratings per Category: Domestic vs International Routes', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Average Rating', fontsize=14)
plt.xticks(rotation=45, ha='right')


handles, labels = plt.gca().get_legend_handles_labels()
new_labels = ['Domestic' if label == 'True' else 'International' for label in labels]
plt.legend(handles=handles, labels=new_labels, title='Route Type', title_fontsize='13', fontsize='12')

plt.tight_layout()
plt.show()

# %%
# Check average ratings for a specific category and route type
average_ratings.loc[average_ratings['is_domestic'] == 0, rating_columns]  # International
average_ratings.loc[average_ratings['is_domestic'] == 1, rating_columns]  # Domestic
# Out:
#    seat_comfort  cabin_staff_service  food_&_beverages  ground_service  \
# 1      2.605263             2.903509          1.210526        2.263158
#
#    wifi_&_connectivity  value_for_money  inflight_entertainment
# 1            -0.298246         2.377193               -0.105263

# %%
nz_reviews_with_routes_df.to_csv("../dataset/nz_reviews_with_routes.csv", index=False)
nz_reviews_with_routes_df
# Out:
#            date                             header  rating        aircraft  \
# 0    2024-09-15                Service was so good      10             NaN
# 1    2024-09-12  a highly disappointing experience       4             NaN
# 2    2024-08-29               the legroom was huge       9            A320
# 3    2024-08-19           getting worse by the day       3             NaN
# 4    2024-08-13    never fly Air New Zealand again       1          ATR-72
# ..          ...                                ...     ...             ...
# 589  2015-07-14    Air New Zealand customer review       4      Boeing 777
# 590  2015-07-03    Air New Zealand customer review       4        B777-300
# 591  2015-06-29    Air New Zealand customer review      10  Boeing 777-300
# 592  2015-06-26    Air New Zealand customer review       9         777-300
# 593  2015-06-15    Air New Zealand customer review       9  Boeing 777-300
#
#     type_of_traveller        seat_type                             route  \
# 0            Business    Economy Class                Melbourne to Tokyo
# 1        Solo Leisure    Economy Class  Raratonga to Auckland via Taipei
# 2      Family Leisure    Economy Class            Auckland to Queenstown
# 3            Business    Economy Class                Auckland to Napier
# 4      Family Leisure    Economy Class                Napier to Auckland
# ..                ...              ...                               ...
# 589      Solo Leisure    Economy Class             London to Los Angeles
# 590          Business    Economy Class                   Auckland to LAX
# 591      Solo Leisure   Business Class           Los Angeles to Auckland
# 592          Business   Business Class                LAX to BNE via AKL
# 593      Solo Leisure  Premium Economy           Los Angeles to Auckland
#
#         date_flown  seat_comfort  cabin_staff_service  ...  \
# 0      August 2024           5.0                  5.0  ...
# 1      August 2024           3.0                  4.0  ...
# 2    December 2023           5.0                  5.0  ...
# 3      August 2024           4.0                  5.0  ...
# 4        June 2024           3.0                  4.0  ...
# ..             ...           ...                  ...  ...
# 589      June 2015           1.0                  2.0  ...
# 590      June 2015           2.0                  4.0  ...
# 591      June 2015           5.0                  5.0  ...
# 592      June 2015           5.0                  5.0  ...
# 593      June 2015           5.0                  5.0  ...
#
#      textblob_sentiment  vader_sentiment  rating_sentiment  year    departure  \
# 0              Positive         Positive          Positive  2024    melbourne
# 1              Negative         Negative           Neutral  2024    raratonga
# 2              Positive         Positive          Positive  2024     auckland
# 3              Negative         Negative          Negative  2024     auckland
# 4              Negative         Negative          Negative  2024       napier
# ..                  ...              ...               ...   ...          ...
# 589            Positive         Positive           Neutral  2015       london
# 590            Positive         Positive           Neutral  2015     auckland
# 591            Positive         Positive          Positive  2015  los angeles
# 592            Positive         Positive          Positive  2015          lax
# 593            Positive         Positive          Positive  2015  los angeles
#
#      departure_country      arrival arrival_country     via is_domestic
# 0                   AU        tokyo              JP    None       False
# 1                 None     auckland              NZ  Taipei       False
# 2                   NZ   queenstown              NZ    None        True
# 3                   NZ       napier              NZ    None        True
# 4                   NZ     auckland              NZ    None        True
# ..                 ...          ...             ...     ...         ...
# 589                 US  los angeles              US    None       False
# 590                 NZ          lax              US    None       False
# 591                 US     auckland              NZ    None       False
# 592                 US          bne              AU     AKL       False
# 593                 US     auckland              NZ    None       False
#
# [562 rows x 28 columns]

# %% [markdown]
# # Do customer reviews improve over time?

# %%
# Convert 'date' to datetime and extract the year
reviews_df['year'] = pd.to_datetime(nz_reviews_with_routes_df['date'], format='%Y-%m-%d').dt.year

# Number of reviews aggregated by year and sentiment
sentiment_by_year = reviews_df.groupby(['year', 'vader_sentiment']).size().unstack(fill_value=0)

sentiment_by_year
# Out:
# vader_sentiment  Negative  Neutral  Positive
# year
# 2015.0                  9        2        33
# 2016.0                 13        0        61
# 2017.0                 17        2        51
# 2018.0                 33        1        44
# 2019.0                 45        1        35
# 2020.0                 26        2        17
# 2021.0                 15        1         9
# 2022.0                 26        4        22
# 2023.0                 38        1        29
# 2024.0                 12        1        12

# %%
from sklearn.linear_model import LinearRegression

# Convert years to a numpy array
years = sentiment_by_year.index.values.reshape(-1, 1)


plt.figure(figsize=(12, 8))

# Linear regression for each sentiment category
for sentiment in sentiment_by_year.columns:
    counts = sentiment_by_year[sentiment].values
    model = LinearRegression().fit(years, counts)
    trend_line = model.predict(years)
    plt.plot(years, trend_line, label=f'{sentiment} Trend', linestyle='--')

# Plot actual data
for sentiment in sentiment_by_year.columns:
    plt.plot(sentiment_by_year.index, sentiment_by_year[sentiment], marker='o', label=f'{sentiment} Actual')

plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Number of Reviews', fontsize=14, fontweight='bold')
plt.title('Total Reviews by Year and Sentiment', fontsize=16, fontweight='bold')
plt.legend(title='Sentiment')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # What key themes emerge from Air New Zealand's customer reviews across different sentiments?

# %%
reviews_df = nz_reviews_with_routes_df
reviews_df.head()
# Out:
#          date                             header  rating aircraft  \
# 0  2024-09-15                Service was so good      10      NaN
# 1  2024-09-12  a highly disappointing experience       4      NaN
# 2  2024-08-29               the legroom was huge       9     A320
# 3  2024-08-19           getting worse by the day       3      NaN
# 4  2024-08-13    never fly Air New Zealand again       1   ATR-72
#
#   type_of_traveller      seat_type                             route  \
# 0          Business  Economy Class                Melbourne to Tokyo
# 1      Solo Leisure  Economy Class  Raratonga to Auckland via Taipei
# 2    Family Leisure  Economy Class            Auckland to Queenstown
# 3          Business  Economy Class                Auckland to Napier
# 4    Family Leisure  Economy Class                Napier to Auckland
#
#       date_flown  seat_comfort  cabin_staff_service  ...  textblob_sentiment  \
# 0    August 2024           5.0                  5.0  ...            Positive
# 1    August 2024           3.0                  4.0  ...            Negative
# 2  December 2023           5.0                  5.0  ...            Positive
# 3    August 2024           4.0                  5.0  ...            Negative
# 4      June 2024           3.0                  4.0  ...            Negative
#
#    vader_sentiment  rating_sentiment  year  departure  departure_country  \
# 0         Positive          Positive  2024  melbourne                 AU
# 1         Negative           Neutral  2024  raratonga               None
# 2         Positive          Positive  2024   auckland                 NZ
# 3         Negative          Negative  2024   auckland                 NZ
# 4         Negative          Negative  2024     napier                 NZ
#
#       arrival arrival_country     via is_domestic
# 0       tokyo              JP    None       False
# 1    auckland              NZ  Taipei       False
# 2  queenstown              NZ    None        True
# 3      napier              NZ    None        True
# 4    auckland              NZ    None        True
#
# [5 rows x 28 columns]

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from collections import Counter
from nltk.util import ngrams
import re

# %%
import nltk
import os

# Add the NLTK data path (make sure the path is correct)
nltk_data_path = '../dashboard/nltk_data'
nltk.data.path.append(nltk_data_path)


# Initialize stop words and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# Common words to exclude from analysis
excluded_terms = ["air_new_zealand", "flight", "auckland", "christchurch", "wellington", 
                  "new", "zealand", "air", "nz", "even_though", "via", "av", "sec"]

# Function to preprocess text
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = " ".join([lemmatizer.lemmatize(word) for word in text.split() if word not in stop_words])
    return text

# Function to generate exactly 3-word n-grams and join words with underscores
def generate_ngrams(text, n=3):
    words = text.split()
    # Generate only 4-word n-grams
    ngrams_list = ["_".join(ngram) for ngram in ngrams(words, n)]
    return ngrams_list


# Function to get top N n-grams while excluding certain terms
def get_top_n_ngrams(sentiment_reviews, n=20):
    all_ngrams = []
    for review in sentiment_reviews:
        all_ngrams.extend(generate_ngrams(review)) 
    
    # Remove excluded terms
    filtered_ngrams = [ngram for ngram in all_ngrams if all(term not in ngram for term in excluded_terms)]
    
    # Count frequencies of remaining n-grams
    ngram_freq = Counter(filtered_ngrams)
    return ngram_freq.most_common(n)

# Preprocess the reviews
reviews_df['cleaned_review'] = reviews_df['review_content'].apply(preprocess_text)

# %%
# Get the top 10 n-grams for each sentiment
positive_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Positive']['cleaned_review']
negative_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Negative']['cleaned_review']
neutral_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Neutral']['cleaned_review']

top_positive_ngrams = get_top_n_ngrams(positive_reviews, 20)
top_negative_ngrams = get_top_n_ngrams(negative_reviews, 20)
top_neutral_ngrams = get_top_n_ngrams(neutral_reviews, 5)

# %%
# Function to plot the n-gram frequencies
def plot_ngram_frequencies(ngram_freq, title):
    ngrams, frequencies = zip(*ngram_freq)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.xlabel('Frequency', fontsize=14)
    plt.ylabel('N-grams', fontsize=14)
    plt.show()

# Plot the n-gram frequencies for each sentiment
plot_ngram_frequencies(top_positive_ngrams, 'Top 20 N-grams in Positive Reviews')
plot_ngram_frequencies(top_negative_ngrams, 'Top 20 N-grams in Negative Reviews')
plot_ngram_frequencies(top_neutral_ngrams, 'Top 5 N-grams in Neutral Reviews')
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/3469339041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(frequencies), y=list(ngrams), palette='viridis')

# %%
from PIL import Image
from wordcloud import WordCloud

# %%
# Load the airplane mask image
mask = np.array(Image.open('../static/airplane-vector-36294843 copy.jpg'))

# %%
def preprocess_ngrams(ngram_freq):
    # Split multi-word n-grams into individual words
    word_list = []
    for ngram, freq in ngram_freq.items():
        words = ngram.split('_')
        word_list.extend(words * freq)
    return Counter(word_list)

def plot_wordcloud(ngram_freq, title, mask):
    # Preprocess n-grams to individual words
    word_freq_dict = preprocess_ngrams(ngram_freq)
    
    # Create and generate the word cloud
    wc = WordCloud(width=800, height=400, background_color='white', colormap='viridis', mask=mask).generate_from_frequencies(word_freq_dict)
    
    # Plot the word cloud
    plt.figure(figsize=(10, 6))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(title, fontsize=16, fontweight='bold')
    plt.show()

# Get the top 20 n-grams for each sentiment
positive_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Positive']['cleaned_review']
negative_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Negative']['cleaned_review']
neutral_reviews = reviews_df[reviews_df['vader_sentiment'] == 'Neutral']['cleaned_review']

top_positive_ngrams = get_top_n_ngrams(positive_reviews, 20)
top_negative_ngrams = get_top_n_ngrams(negative_reviews, 20)
top_neutral_ngrams = get_top_n_ngrams(neutral_reviews, 10)



# Plot the word clouds for each sentiment
plot_wordcloud(dict(top_positive_ngrams), 'Word Cloud for Positive Reviews', mask)
plot_wordcloud(dict(top_negative_ngrams), 'Word Cloud for Negative Reviews', mask)
plot_wordcloud(dict(top_neutral_ngrams), 'Word Cloud for Neutral Reviews', mask)

# %% [markdown]
# # Which type of traveler gives the highest/lowest ratings?

# %%
cleaned_reviews = "../dataset/nz_reviews_with_routes.csv"
reviews_df = pd.read_csv(cleaned_reviews)

reviews_df.head()
# Out:
#          date                             header  rating aircraft  \
# 0  2024-09-15                Service was so good      10      NaN
# 1  2024-09-12  a highly disappointing experience       4      NaN
# 2  2024-08-29               the legroom was huge       9     A320
# 3  2024-08-19           getting worse by the day       3      NaN
# 4  2024-08-13    never fly Air New Zealand again       1   ATR-72
#
#   type_of_traveller      seat_type                             route  \
# 0          Business  Economy Class                Melbourne to Tokyo
# 1      Solo Leisure  Economy Class  Raratonga to Auckland via Taipei
# 2    Family Leisure  Economy Class            Auckland to Queenstown
# 3          Business  Economy Class                Auckland to Napier
# 4    Family Leisure  Economy Class                Napier to Auckland
#
#       date_flown  seat_comfort  cabin_staff_service  ...  textblob_sentiment  \
# 0    August 2024           5.0                  5.0  ...            Positive
# 1    August 2024           3.0                  4.0  ...            Negative
# 2  December 2023           5.0                  5.0  ...            Positive
# 3    August 2024           4.0                  5.0  ...            Negative
# 4      June 2024           3.0                  4.0  ...            Negative
#
#    vader_sentiment  rating_sentiment  year  departure  departure_country  \
# 0         Positive          Positive  2024  melbourne                 AU
# 1         Negative           Neutral  2024  raratonga                NaN
# 2         Positive          Positive  2024   auckland                 NZ
# 3         Negative          Negative  2024   auckland                 NZ
# 4         Negative          Negative  2024     napier                 NZ
#
#       arrival arrival_country     via is_domestic
# 0       tokyo              JP     NaN       False
# 1    auckland              NZ  Taipei       False
# 2  queenstown              NZ     NaN        True
# 3      napier              NZ     NaN        True
# 4    auckland              NZ     NaN        True
#
# [5 rows x 28 columns]

# %%
reviews_df.columns
# Out:
# Index(['date', 'header', 'rating', 'aircraft', 'type_of_traveller',
#        'seat_type', 'route', 'date_flown', 'seat_comfort',
#        'cabin_staff_service', 'food_&_beverages', 'ground_service',
#        'wifi_&_connectivity', 'value_for_money', 'recommended',
#        'inflight_entertainment', 'verified_status', 'review_content',
#        'textblob_sentiment', 'vader_sentiment', 'rating_sentiment', 'year',
#        'departure', 'departure_country', 'arrival', 'arrival_country', 'via',
#        'is_domestic'],
#       dtype='object')

# %%
# Checking the unique types of travelers
reviews_df['type_of_traveller'].unique()

# Checking the distribution of ratings
reviews_df['rating'].describe()
# Out:
# count    562.000000
# mean       4.807829
# std        3.531182
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        9.000000
# max       10.000000
# Name: rating, dtype: float64

# %%
# Grouping by type of traveller and calculating mean and median ratings
traveller_rating_summary = reviews_df.groupby('type_of_traveller')['rating'].agg(['mean', 'median', 'count']).reset_index()

# Sorting to find the highest and lowest mean ratings
traveller_rating_summary = traveller_rating_summary.sort_values(by='mean', ascending=False)
traveller_rating_summary
# Out:
#   type_of_traveller      mean  median  count
# 3      Solo Leisure  5.029851     4.0    201
# 1    Couple Leisure  4.901639     4.0    183
# 0          Business  4.694118     3.0     85
# 2    Family Leisure  4.247312     3.0     93

# %%
labels = traveller_rating_summary['type_of_traveller']
average_ratings = traveller_rating_summary['mean']

plt.figure(figsize=(8, 8))
plt.pie(average_ratings, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("viridis"))
plt.title('Average Rating Distribution by Type of Traveler')
plt.axis('equal')
plt.show()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
reviews_df
# Out:
#            date                             header  rating        aircraft  \
# 0    2024-09-15                Service was so good      10             NaN
# 1    2024-09-12  a highly disappointing experience       4             NaN
# 2    2024-08-29               the legroom was huge       9            A320
# 3    2024-08-19           getting worse by the day       3             NaN
# 4    2024-08-13    never fly Air New Zealand again       1          ATR-72
# ..          ...                                ...     ...             ...
# 557  2015-07-14    Air New Zealand customer review       4      Boeing 777
# 558  2015-07-03    Air New Zealand customer review       4        B777-300
# 559  2015-06-29    Air New Zealand customer review      10  Boeing 777-300
# 560  2015-06-26    Air New Zealand customer review       9         777-300
# 561  2015-06-15    Air New Zealand customer review       9  Boeing 777-300
#
#     type_of_traveller        seat_type                             route  \
# 0            Business    Economy Class                Melbourne to Tokyo
# 1        Solo Leisure    Economy Class  Raratonga to Auckland via Taipei
# 2      Family Leisure    Economy Class            Auckland to Queenstown
# 3            Business    Economy Class                Auckland to Napier
# 4      Family Leisure    Economy Class                Napier to Auckland
# ..                ...              ...                               ...
# 557      Solo Leisure    Economy Class             London to Los Angeles
# 558          Business    Economy Class                   Auckland to LAX
# 559      Solo Leisure   Business Class           Los Angeles to Auckland
# 560          Business   Business Class                LAX to BNE via AKL
# 561      Solo Leisure  Premium Economy           Los Angeles to Auckland
#
#         date_flown  seat_comfort  cabin_staff_service  ...  \
# 0      August 2024           5.0                  5.0  ...
# 1      August 2024           3.0                  4.0  ...
# 2    December 2023           5.0                  5.0  ...
# 3      August 2024           4.0                  5.0  ...
# 4        June 2024           3.0                  4.0  ...
# ..             ...           ...                  ...  ...
# 557      June 2015           1.0                  2.0  ...
# 558      June 2015           2.0                  4.0  ...
# 559      June 2015           5.0                  5.0  ...
# 560      June 2015           5.0                  5.0  ...
# 561      June 2015           5.0                  5.0  ...
#
#      textblob_sentiment  vader_sentiment  rating_sentiment  year    departure  \
# 0              Positive         Positive          Positive  2024    melbourne
# 1              Negative         Negative           Neutral  2024    raratonga
# 2              Positive         Positive          Positive  2024     auckland
# 3              Negative         Negative          Negative  2024     auckland
# 4              Negative         Negative          Negative  2024       napier
# ..                  ...              ...               ...   ...          ...
# 557            Positive         Positive           Neutral  2015       london
# 558            Positive         Positive           Neutral  2015     auckland
# 559            Positive         Positive          Positive  2015  los angeles
# 560            Positive         Positive          Positive  2015          lax
# 561            Positive         Positive          Positive  2015  los angeles
#
#      departure_country      arrival arrival_country     via is_domestic
# 0                   AU        tokyo              JP     NaN       False
# 1                  NaN     auckland              NZ  Taipei       False
# 2                   NZ   queenstown              NZ     NaN        True
# 3                   NZ       napier              NZ     NaN        True
# 4                   NZ     auckland              NZ     NaN        True
# ..                 ...          ...             ...     ...         ...
# 557                 US  los angeles              US     NaN       False
# 558                 NZ          lax              US     NaN       False
# 559                 US     auckland              NZ     NaN       False
# 560                 US          bne              AU     AKL       False
# 561                 US     auckland              NZ     NaN       False
#
# [562 rows x 28 columns]

# %%
# Group by type of traveler and sentiment label
sentiment_distribution = reviews_df.groupby(['type_of_traveller', 'vader_sentiment']).size().unstack(fill_value=0)

# Normalize to get percentage distribution
sentiment_distribution_percentage = sentiment_distribution.div(sentiment_distribution.sum(axis=1), axis=0)

# Display the sentiment distribution as a percentage
sentiment_distribution_percentage
# Out:
# vader_sentiment    Negative   Neutral  Positive
# type_of_traveller
# Business           0.388235  0.011765  0.600000
# Couple Leisure     0.442623  0.032787  0.524590
# Family Leisure     0.516129  0.021505  0.462366
# Solo Leisure       0.407960  0.019900  0.572139

# %%
traveller_types = sentiment_distribution.index

fig, axes = plt.subplots(1, len(traveller_types), figsize=(18, 6))

colors = ['#ff9999','#66b3ff','#99ff99']

# Iterate through each type of traveler and create a pie chart
for i, traveller_type in enumerate(traveller_types):
    sentiments = sentiment_distribution.loc[traveller_type]
    
    axes[i].pie(sentiments, labels=sentiments.index, autopct='%1.1f%%', startangle=90, colors=colors)
    
    axes[i].set_title(traveller_type)

plt.tight_layout()
plt.suptitle('Sentiment Distribution for Different Types of Travelers', y=1.05, fontsize=16)
plt.show()

# %% [markdown]
# # How do ratings vary by Seat Type (e.g. Economy, Business)?

# %%
# Group by seat type and calculate rating statistics
seat_rating_summary = reviews_df.groupby('seat_type')['rating'].agg(['mean', 'median', 'count']).reset_index()

# Sort the values to see which seat types have the highest/lowest ratings
seat_rating_summary = seat_rating_summary.sort_values(by='mean', ascending=False)

# Display the summary
seat_rating_summary
# Out:
#          seat_type      mean  median  count
# 0   Business Class  6.697674     8.0     86
# 2  Premium Economy  5.957447     8.0     47
# 1    Economy Class  4.303030     3.0    429

# %%
# Set the figure size for better readability
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the mean ratings by seat type
sns.barplot(x='seat_type', y='mean', data=seat_rating_summary, palette='coolwarm')

# Add labels and title
plt.title('Average Ratings by Seat Type')
plt.xlabel('Seat Type')
plt.ylabel('Average Rating')

# Display the plot
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/768762854.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y='mean', data=seat_rating_summary, palette='coolwarm')

# %%
# Set the figure size for better readability
plt.figure(figsize=(12, 6))

# Create a count plot to visualize the number of reviews for each rating per seat type
sns.countplot(x='rating', hue='seat_type', data=reviews_df, palette='coolwarm')

# Add labels and title
plt.title('Rating Distribution by Seat Type')
plt.xlabel('Rating') 
plt.ylabel('Count of Reviews')

# Display the plot
plt.show()

# %%
# List of rating columns excluding 'wifi_&_connectivity'
rating_columns = ['seat_comfort', 'cabin_staff_service', 'food_&_beverages', 'ground_service', 'value_for_money', 'wifi_&_connectivity', 'inflight_entertainment']

# %%
# Group by seat type and calculate the mean ratings for the selected columns
category_rating_summary = reviews_df.groupby('seat_type')[rating_columns].mean().reset_index()

# Display the summary
category_rating_summary
# Out:
#          seat_type  seat_comfort  cabin_staff_service  food_&_beverages  \
# 0   Business Class      3.616279             4.058140          3.593023
# 1    Economy Class      2.508159             2.715618          1.734266
# 2  Premium Economy      3.340426             3.404255          2.957447
#
#    ground_service  value_for_money  wifi_&_connectivity  \
# 0        3.290698         3.430233             0.255814
# 1        2.470862         2.456876             0.041958
# 2        3.361702         3.255319             0.255319
#
#    inflight_entertainment
# 0                3.255814
# 1                1.720280
# 2                3.021277

# %%
# Set the figure size for better readability
plt.figure(figsize=(14, 12))  # Adjusted size to fit all subplots

# Loop through each rating column and create a subplot
for i, column in enumerate(rating_columns):
    plt.subplot(4, 2, i+1)  # Create a 4x2 grid for subplots
    
    # Create a bar plot for the current category
    sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
    
    # Add title and labels
    plt.title(f'Average {column.replace("_", " ").title()} by Seat Type')
    plt.xlabel('Seat Type')
    plt.ylabel(f'Average {column.replace("_", " ").title()}')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
# /var/folders/zc/zmsjc2n90lg57tm5x4g9t1rw0000gn/T/ipykernel_5971/2884457515.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='seat_type', y=column, data=reviews_df, palette='coolwarm')
